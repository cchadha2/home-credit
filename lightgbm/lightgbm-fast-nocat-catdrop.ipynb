# %%
import os
import math
import time

from contextlib import contextmanager
import numpy as np
import pandas as pd
from IPython.display import display
import lightgbm
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import KFold, StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns

# %%
@contextmanager
def timer(title):
    t0 = time.time()
    yield
    print("{} - done in {:.0f}s".format(title, time.time() - t0))

# %%
def display_importances(feature_importance_df_):
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(by="importance", ascending=False)[:40].index
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]
    plt.figure(figsize=(12, 10))
    sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False))
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout()
    plt.savefig('../output/lgbm_importances_bayesian.png')

# %%
def kfold_lightgbm(df, num_folds, stratified = False, epochs = 1, corr_save = False, importance_save = False):
    df = df.drop('Unnamed: 0', axis = 1)  
    
    # Divide in training/validation and test data
    train_df = df[df['TARGET'].notnull()]
    test_df = df[df['TARGET'].isnull()]
    
    # Correlation csv processing
    if corr_save == True:
        target_corr = train_df.corr()['TARGET'].sort_values()
        corr_df = pd.DataFrame()
        corr_df['feature'] = target_corr.index
        corr_df['corr'] = target_corr.values
        corr_df = corr_df[corr_df['feature'] != 'feature']
        corr_df.to_csv('../output/correlation.csv')
        del target_corr, corr_df


    cat_cols = ['FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'FLAG_MOBIL', 'FLAG_EMP_PHONE',
                'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL',
                'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION', 'LIVE_REGION_NOT_WORK_REGION', 
                'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY',
                'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5', 'FLAG_DOCUMENT_6',
                'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_9', 'FLAG_DOCUMENT_11', 
                'FLAG_DOCUMENT_18', 'CODE_GENDER', 'NAME_CONTRACT_TYPE',
                'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY', 'EMERGENCYSTATE_MODE',
                'HOUSETYPE_MODE', 'FONDKAPREMONT_MODE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS',
                'NAME_HOUSING_TYPE', 'NAME_TYPE_SUITE', 'WALLSMATERIAL_MODE','WEEKDAY_APPR_PROCESS_START',
                'HOUR_APPR_PROCESS_START', 'NAME_INCOME_TYPE', 'OCCUPATION_TYPE', 'ORGANIZATION_TYPE']
    
    included_cat_cols = [i for i in cat_cols if i in list(train_df.columns)]
    
    # Delete variables from memory 
    del df, cat_cols

    print("Starting LightGBM. Train shape: {}, test shape: {}".format(train_df.shape, test_df.shape))
    # Initialise predictions and importance dataframes and epoch weights
    sub_df = test_df[['SK_ID_CURR']].copy()
    sub_df['TARGET'] = 0
    ep_ave = 1/epochs
    epv_preds = np.zeros(train_df.shape[0])
    feature_importance_df = pd.DataFrame()    
    
    for n in range(epochs):
        
        print('Epoch number {} of {} starting'.format(n+1, epochs))
        # Cross validation model
        if epochs == 1:
            if stratified:
                folds = StratifiedKFold(n_splits= num_folds, shuffle=True, random_state=1001)
            else:
                folds = KFold(n_splits= num_folds, shuffle=True, random_state=1001)
        else:
            if stratified:
                folds = StratifiedKFold(n_splits= num_folds, shuffle=True)
            else:
                folds = KFold(n_splits= num_folds, shuffle=True)
        # Create arrays and dataframes to store results
        oof_preds = np.zeros(train_df.shape[0])
        sub_preds = np.zeros(test_df.shape[0])
        feats = [f for f in train_df.columns if f not in ['TARGET','SK_ID_CURR','SK_ID_BUREAU','SK_ID_PREV','index']]

        for n_fold, (train_idx, valid_idx) in enumerate(folds.split(train_df[feats], train_df['TARGET'])):
            dtrain = lightgbm.Dataset(data=train_df[feats].iloc[train_idx], 
                                 label=train_df['TARGET'].iloc[train_idx], 
                                 free_raw_data=False, silent=True)#,
#                                  categorical_feature=included_cat_cols)
            dvalid = lightgbm.Dataset(data=train_df[feats].iloc[valid_idx], 
                                 label=train_df['TARGET'].iloc[valid_idx], 
                                 free_raw_data=False, silent=True)#,
#                                  categorical_feature=included_cat_cols)

            # LightGBM parameters found by Bayesian optimization
            params = {
                'objective': 'binary',
                'boosting_type': 'gbdt', # 'goss'
                'nthread': 4,
                'learning_rate': 0.02,  # 02,
                'num_leaves': 20,
                'colsample_bytree': 0.9497036,
                'subsample': 0.8715623,
                'subsample_freq': 1,
                'max_depth': 8,
                'reg_alpha': 0.041545473,
                'reg_lambda': 0.0735294,
                'min_split_gain': 0.0222415,
                'min_child_weight': 60, #39.3259775
                'seed': 0,
                'verbose': -1,
                'metric': 'auc',
            }

            clf = lightgbm.train(
                params=params,
                train_set=dtrain,
                num_boost_round=10000,
                valid_sets=[dtrain, dvalid],
                early_stopping_rounds= 200,
                verbose_eval=100
            )

            oof_preds[valid_idx] = clf.predict(dvalid.data)
            sub_preds += clf.predict(test_df[feats]) / folds.n_splits

            fold_importance_df = pd.DataFrame()
            fold_importance_df["feature"] = feats
            fold_importance_df["importance"] = clf.feature_importance(importance_type='gain')
            fold_importance_df["fold"] = n_fold + 1
            feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
            print('Fold %2d AUC : %.6f' % (n_fold + 1, roc_auc_score(dvalid.label, oof_preds[valid_idx])))
            del clf, dtrain, dvalid
            
        print('Full AUC score %.6f' % roc_auc_score(train_df['TARGET'], oof_preds))
        # Write submission file and plot feature importance
        sub_df['TARGET'] += ep_ave*sub_preds
        epv_preds += ep_ave*oof_preds
        print('Epoch number {} of {} ended'.format(n+1, epochs))
        
    sub_df[['SK_ID_CURR', 'TARGET']].to_csv(submission_file_name, index= False)
    print('Full AUC score over all epochs %.6f' % roc_auc_score(train_df['TARGET'], epv_preds))
    display_importances(feature_importance_df)
    
    # Save feature importance df as csv
    if importance_save == True:
        feature_importance_df = feature_importance_df.groupby('feature').agg('mean').drop('fold', axis = 1).sort_values('importance')
        feature_importance_df.to_csv('../output/importance_3.2.csv')

# %%
def main():
    
    df = pd.read_csv('../data/processed_data_3.2_catdrop.csv')
    
    with timer("Run LightGBM with kfold"):
        feature_importance_df = kfold_lightgbm(df,
                                               num_folds=5,
                                               stratified=False,
                                               epochs=1,
                                               corr_save=False,
                                               importance_save=False) 

if __name__ == "__main__":
    submission_file_name = "../predictions/lightgbm_pred_nocat_catdrop.csv"
    with timer("Full model run"):
        main()
# Out:
# Starting LightGBM. Train shape: (307511, 627), test shape: (48744, 627)
# Epoch number 1 of 1 starting
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.764005	valid_1's auc: 0.756318
# [200]	training's auc: 0.783933	valid_1's auc: 0.771362
# [300]	training's auc: 0.795294	valid_1's auc: 0.778412
# [400]	training's auc: 0.803467	valid_1's auc: 0.782654
# [500]	training's auc: 0.81026	valid_1's auc: 0.785333
# [600]	training's auc: 0.816213	valid_1's auc: 0.786942
# [700]	training's auc: 0.821513	valid_1's auc: 0.788071
# [800]	training's auc: 0.826331	valid_1's auc: 0.788833
# [900]	training's auc: 0.830876	valid_1's auc: 0.78951
# [1000]	training's auc: 0.835137	valid_1's auc: 0.789869
# [1100]	training's auc: 0.839378	valid_1's auc: 0.790294
# [1200]	training's auc: 0.84331	valid_1's auc: 0.790764
# [1300]	training's auc: 0.847093	valid_1's auc: 0.79105
# [1400]	training's auc: 0.850825	valid_1's auc: 0.79105
# [1500]	training's auc: 0.854491	valid_1's auc: 0.791297
# [1600]	training's auc: 0.857906	valid_1's auc: 0.791331
# [1700]	training's auc: 0.861183	valid_1's auc: 0.791365
# Early stopping, best iteration is:
# [1523]	training's auc: 0.855271	valid_1's auc: 0.791409
# Fold  1 AUC : 0.791335
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.763832	valid_1's auc: 0.75335
# [200]	training's auc: 0.783578	valid_1's auc: 0.770252
# [300]	training's auc: 0.795003	valid_1's auc: 0.777731
# [400]	training's auc: 0.803311	valid_1's auc: 0.782108
# [500]	training's auc: 0.810187	valid_1's auc: 0.784725
# [600]	training's auc: 0.816306	valid_1's auc: 0.786617
# [700]	training's auc: 0.821709	valid_1's auc: 0.787749
# [800]	training's auc: 0.826418	valid_1's auc: 0.788615
# [900]	training's auc: 0.831068	valid_1's auc: 0.789352
# [1000]	training's auc: 0.835397	valid_1's auc: 0.789853
# [1100]	training's auc: 0.839401	valid_1's auc: 0.790246
# [1200]	training's auc: 0.843392	valid_1's auc: 0.790623
# [1300]	training's auc: 0.847131	valid_1's auc: 0.790833
# [1400]	training's auc: 0.850793	valid_1's auc: 0.791088
# [1500]	training's auc: 0.854228	valid_1's auc: 0.791305
# [1600]	training's auc: 0.8577	valid_1's auc: 0.79144
# [1700]	training's auc: 0.861078	valid_1's auc: 0.791536
# [1800]	training's auc: 0.864184	valid_1's auc: 0.791709
# [1900]	training's auc: 0.867418	valid_1's auc: 0.791668
# [2000]	training's auc: 0.870589	valid_1's auc: 0.791834
# [2100]	training's auc: 0.873591	valid_1's auc: 0.792072
# [2200]	training's auc: 0.876431	valid_1's auc: 0.792056
# [2300]	training's auc: 0.879226	valid_1's auc: 0.792032
# Early stopping, best iteration is:
# [2149]	training's auc: 0.874965	valid_1's auc: 0.792113
# Fold  2 AUC : 0.792112
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.764882	valid_1's auc: 0.749423
# [200]	training's auc: 0.785158	valid_1's auc: 0.764755
# [300]	training's auc: 0.796514	valid_1's auc: 0.771853
# [400]	training's auc: 0.804704	valid_1's auc: 0.775894
# [500]	training's auc: 0.811389	valid_1's auc: 0.778268
# [600]	training's auc: 0.817327	valid_1's auc: 0.780028
# [700]	training's auc: 0.822594	valid_1's auc: 0.781243
# [800]	training's auc: 0.827434	valid_1's auc: 0.782254
# [900]	training's auc: 0.832025	valid_1's auc: 0.782849
# [1000]	training's auc: 0.836236	valid_1's auc: 0.783458
# [1100]	training's auc: 0.840275	valid_1's auc: 0.783963
# [1200]	training's auc: 0.844319	valid_1's auc: 0.784313
# [1300]	training's auc: 0.848077	valid_1's auc: 0.784572
# [1400]	training's auc: 0.851685	valid_1's auc: 0.784797
# [1500]	training's auc: 0.855196	valid_1's auc: 0.784992
# [1600]	training's auc: 0.858763	valid_1's auc: 0.785209
# [1700]	training's auc: 0.861946	valid_1's auc: 0.78529
# [1800]	training's auc: 0.865237	valid_1's auc: 0.785431
# [1900]	training's auc: 0.868399	valid_1's auc: 0.78548
# [2000]	training's auc: 0.871374	valid_1's auc: 0.785572
# [2100]	training's auc: 0.87441	valid_1's auc: 0.785687
# [2200]	training's auc: 0.877287	valid_1's auc: 0.785724
# [2300]	training's auc: 0.880165	valid_1's auc: 0.785629
# [2400]	training's auc: 0.8829	valid_1's auc: 0.785729
# [2500]	training's auc: 0.885464	valid_1's auc: 0.785859
# [2600]	training's auc: 0.888053	valid_1's auc: 0.785841
# Early stopping, best iteration is:
# [2494]	training's auc: 0.88531	valid_1's auc: 0.785889
# Fold  3 AUC : 0.785867
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.764733	valid_1's auc: 0.753851
# [200]	training's auc: 0.784969	valid_1's auc: 0.768018
# [300]	training's auc: 0.796401	valid_1's auc: 0.774296
# [400]	training's auc: 0.804732	valid_1's auc: 0.778227
# [500]	training's auc: 0.81153	valid_1's auc: 0.780728
# [600]	training's auc: 0.817491	valid_1's auc: 0.782542
# [700]	training's auc: 0.822868	valid_1's auc: 0.783836
# [800]	training's auc: 0.827772	valid_1's auc: 0.784495
# [900]	training's auc: 0.832387	valid_1's auc: 0.785041
# [1000]	training's auc: 0.836718	valid_1's auc: 0.785585
# [1100]	training's auc: 0.840683	valid_1's auc: 0.786006
# [1200]	training's auc: 0.844636	valid_1's auc: 0.786272
# [1300]	training's auc: 0.848458	valid_1's auc: 0.786494
# [1400]	training's auc: 0.852037	valid_1's auc: 0.786699
# [1500]	training's auc: 0.855597	valid_1's auc: 0.786855
# [1600]	training's auc: 0.859125	valid_1's auc: 0.786987
# [1700]	training's auc: 0.86249	valid_1's auc: 0.787148
# [1800]	training's auc: 0.865615	valid_1's auc: 0.787199
# [1900]	training's auc: 0.868731	valid_1's auc: 0.787445
# [2000]	training's auc: 0.871766	valid_1's auc: 0.787552
# [2100]	training's auc: 0.87472	valid_1's auc: 0.787576
# [2200]	training's auc: 0.877636	valid_1's auc: 0.787709
# [2300]	training's auc: 0.880432	valid_1's auc: 0.78788
# [2400]	training's auc: 0.883163	valid_1's auc: 0.787985
# [2500]	training's auc: 0.885733	valid_1's auc: 0.788021
# [2600]	training's auc: 0.888283	valid_1's auc: 0.787971
# [2700]	training's auc: 0.890757	valid_1's auc: 0.78808
# [2800]	training's auc: 0.893283	valid_1's auc: 0.787983
# [2900]	training's auc: 0.895715	valid_1's auc: 0.787776
# Early stopping, best iteration is:
# [2746]	training's auc: 0.891924	valid_1's auc: 0.788124
# Fold  4 AUC : 0.788116
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.76407	valid_1's auc: 0.756857
# [200]	training's auc: 0.784194	valid_1's auc: 0.771481
# [300]	training's auc: 0.795516	valid_1's auc: 0.778067
# [400]	training's auc: 0.803782	valid_1's auc: 0.781752
# [500]	training's auc: 0.810868	valid_1's auc: 0.783908
# [600]	training's auc: 0.816894	valid_1's auc: 0.785273
# [700]	training's auc: 0.822192	valid_1's auc: 0.786185
# [800]	training's auc: 0.826957	valid_1's auc: 0.786865
# [900]	training's auc: 0.831556	valid_1's auc: 0.787307
# [1000]	training's auc: 0.83586	valid_1's auc: 0.787687
# [1100]	training's auc: 0.839928	valid_1's auc: 0.787727
# [1200]	training's auc: 0.843902	valid_1's auc: 0.787823
# [1300]	training's auc: 0.847843	valid_1's auc: 0.787979
# [1400]	training's auc: 0.851543	valid_1's auc: 0.788108
# [1500]	training's auc: 0.855063	valid_1's auc: 0.788166
# [1600]	training's auc: 0.858409	valid_1's auc: 0.788219
# [1700]	training's auc: 0.861807	valid_1's auc: 0.788302
# [1800]	training's auc: 0.864909	valid_1's auc: 0.788253
# Early stopping, best iteration is:
# [1644]	training's auc: 0.859928	valid_1's auc: 0.788385
# Fold  5 AUC : 0.788415
# Full AUC score 0.789153
# Epoch number 1 of 1 ended
# Full AUC score over all epochs 0.789153
# Run LightGBM with kfold - done in 2622s
# Full model run - done in 2657s
