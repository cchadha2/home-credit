# %%
import time

from contextlib import contextmanager
import numpy as np
import pandas as pd
from lightgbm import Dataset, train
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import KFold, StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns

# %%
@contextmanager
def timer(title):
    t0 = time.time()
    yield
    print("{} - done in {:.0f}s".format(title, time.time() - t0))

# %%
def display_importances(feature_importance_df_):
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(by="importance", ascending=False)[:40].index
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]
    plt.figure(figsize=(12, 10))
    sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False))
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout()
    plt.savefig('../output/lgbm_importances.png')

# %%
def kfold_lightgbm(df, num_folds, stratified = False, epochs = 1, corr_save = False, importance_save = False):
    
    # Divide in training/validation and test data
    train_df = df[df['TARGET'].notnull()]
    test_df = df[df['TARGET'].isnull()]
    
    # Correlation csv processing
    if corr_save == True:
        target_corr = train_df.corr()['TARGET'].sort_values()
        corr_df = pd.DataFrame()
        corr_df['feature'] = target_corr.index
        corr_df['corr'] = target_corr.values
        corr_df = corr_df[corr_df['feature'] != 'feature']
        corr_df.to_csv('../output/correlation.csv')
        del target_corr, corr_df
    
    # Delete variables from memory 
    del df

    print("Starting LightGBM. Train shape: {}, test shape: {}".format(train_df.shape, test_df.shape))
    # Initialise predictions and importance dataframes and epoch weights
    sub_df = test_df[['SK_ID_CURR']].copy()
    sub_df['TARGET'] = 0
    ep_ave = 1/epochs
    epv_preds = np.zeros(train_df.shape[0])
    feature_importance_df = pd.DataFrame()    
    
    for n in range(epochs):
        
        print('Epoch number {} of {} starting'.format(n+1, epochs))
        # Cross validation model
        if epochs == 1:
            if stratified:
                folds = StratifiedKFold(n_splits= num_folds, shuffle=True, random_state=1001)
            else:
                folds = KFold(n_splits= num_folds, shuffle=True, random_state=1001)
        else:
            if stratified:
                folds = StratifiedKFold(n_splits= num_folds, shuffle=True)
            else:
                folds = KFold(n_splits= num_folds, shuffle=True)
        # Create arrays and dataframes to store results
        oof_preds = np.zeros(train_df.shape[0])
        sub_preds = np.zeros(test_df.shape[0])
        feats = [f for f in train_df.columns if f not in ['TARGET','SK_ID_CURR','SK_ID_BUREAU','SK_ID_PREV','index']]

        for n_fold, (train_idx, valid_idx) in enumerate(folds.split(train_df[feats], train_df['TARGET'])):
            dtrain = Dataset(data=train_df[feats].iloc[train_idx], 
                                 label=train_df['TARGET'].iloc[train_idx], 
                                 free_raw_data=False, silent=True)
            dvalid = Dataset(data=train_df[feats].iloc[valid_idx], 
                                 label=train_df['TARGET'].iloc[valid_idx], 
                                 free_raw_data=False, silent=True)

            # LightGBM parameters found by Bayesian optimization
            params = {
                'objective': 'binary',
                'boosting_type': 'gbdt', # 'goss'
                'nthread': 4,
                'learning_rate': 0.02,  # 02,
                'num_leaves': 20,
                'colsample_bytree': 0.9497036,
                'subsample': 0.8715623,
                'subsample_freq': 1,
                'max_depth': 8,
                'reg_alpha': 0.041545473,
                'reg_lambda': 0.0735294,
                'min_split_gain': 0.0222415,
                'min_child_weight': 60, #39.3259775
                'seed': 0,
                'verbose': -1,
                'metric': 'auc',
            }

            clf = train(
                params=params,
                train_set=dtrain,
                num_boost_round=10000,
                valid_sets=[dtrain, dvalid],
                early_stopping_rounds= 200,
                verbose_eval=100
            )

            oof_preds[valid_idx] = clf.predict(dvalid.data)
            sub_preds += clf.predict(test_df[feats]) / folds.n_splits

            fold_importance_df = pd.DataFrame()
            fold_importance_df["feature"] = feats
            fold_importance_df["importance"] = clf.feature_importance(importance_type='gain')
            fold_importance_df["fold"] = n_fold + 1
            feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
            print('Fold %2d AUC : %.6f' % (n_fold + 1, roc_auc_score(dvalid.label, oof_preds[valid_idx])))
            del clf, dtrain, dvalid
            
        print('Full AUC score %.6f' % roc_auc_score(train_df['TARGET'], oof_preds))
        # Write submission file and plot feature importance
        sub_df['TARGET'] += ep_ave*sub_preds
        epv_preds += ep_ave*oof_preds
        print('Epoch number {} of {} ended'.format(n+1, epochs))
        
    sub_df[['SK_ID_CURR', 'TARGET']].to_csv(submission_file_name, index= False)
    print('Full AUC score over all epochs %.6f' % roc_auc_score(train_df['TARGET'], epv_preds))
    display_importances(feature_importance_df)
    
    # Save feature importance df as csv
    if importance_save == True:
        feature_importance_df = feature_importance_df.groupby('feature').agg('mean').drop('fold', axis = 1).sort_values('importance')
        feature_importance_df.to_csv('../output/importance_3.3.csv')

# %%
def main():
    
    df = pd.read_csv('../data/processed_data_3.3.csv')
    
    with timer("Run LightGBM with kfold"):
        feature_importance_df = kfold_lightgbm(df,
                                               num_folds=5,
                                               stratified=False,
                                               epochs=1,
                                               corr_save=False,
                                               importance_save=False) 

if __name__ == "__main__":
    submission_file_name = "../predictions/lightgbm_pred.csv"
    with timer("Full model run"):
        main()
# Out:
# Starting LightGBM. Train shape: (307511, 637), test shape: (48744, 637)
# Epoch number 1 of 1 starting
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.76577	valid_1's auc: 0.758082
# [200]	training's auc: 0.785843	valid_1's auc: 0.7738
# [300]	training's auc: 0.797401	valid_1's auc: 0.781435
# [400]	training's auc: 0.805793	valid_1's auc: 0.785791
# [500]	training's auc: 0.812863	valid_1's auc: 0.788653
# [600]	training's auc: 0.819007	valid_1's auc: 0.790558
# [700]	training's auc: 0.824528	valid_1's auc: 0.791953
# [800]	training's auc: 0.829361	valid_1's auc: 0.792896
# [900]	training's auc: 0.833928	valid_1's auc: 0.793444
# [1000]	training's auc: 0.838222	valid_1's auc: 0.793859
# [1100]	training's auc: 0.842364	valid_1's auc: 0.794328
# [1200]	training's auc: 0.846319	valid_1's auc: 0.79473
# [1300]	training's auc: 0.850143	valid_1's auc: 0.794956
# [1400]	training's auc: 0.853859	valid_1's auc: 0.795015
# [1500]	training's auc: 0.85742	valid_1's auc: 0.795236
# [1600]	training's auc: 0.860885	valid_1's auc: 0.795384
# [1700]	training's auc: 0.864189	valid_1's auc: 0.795491
# [1800]	training's auc: 0.867331	valid_1's auc: 0.795577
# [1900]	training's auc: 0.870406	valid_1's auc: 0.795475
# Early stopping, best iteration is:
# [1778]	training's auc: 0.866616	valid_1's auc: 0.795639
# Fold  1 AUC : 0.795588
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.765267	valid_1's auc: 0.755149
# [200]	training's auc: 0.785604	valid_1's auc: 0.772694
# [300]	training's auc: 0.797141	valid_1's auc: 0.78037
# [400]	training's auc: 0.805733	valid_1's auc: 0.78461
# [500]	training's auc: 0.812783	valid_1's auc: 0.787427
# [600]	training's auc: 0.819059	valid_1's auc: 0.789656
# [700]	training's auc: 0.824433	valid_1's auc: 0.790785
# [800]	training's auc: 0.829295	valid_1's auc: 0.791762
# [900]	training's auc: 0.833844	valid_1's auc: 0.792493
# [1000]	training's auc: 0.838204	valid_1's auc: 0.793055
# [1100]	training's auc: 0.842381	valid_1's auc: 0.79368
# [1200]	training's auc: 0.846169	valid_1's auc: 0.793921
# [1300]	training's auc: 0.850036	valid_1's auc: 0.794257
# [1400]	training's auc: 0.853731	valid_1's auc: 0.794513
# [1500]	training's auc: 0.857247	valid_1's auc: 0.794798
# [1600]	training's auc: 0.860711	valid_1's auc: 0.794968
# [1700]	training's auc: 0.864052	valid_1's auc: 0.79516
# [1800]	training's auc: 0.867267	valid_1's auc: 0.795246
# [1900]	training's auc: 0.870358	valid_1's auc: 0.795279
# [2000]	training's auc: 0.873402	valid_1's auc: 0.7954
# [2100]	training's auc: 0.876421	valid_1's auc: 0.795436
# [2200]	training's auc: 0.879332	valid_1's auc: 0.795463
# [2300]	training's auc: 0.882201	valid_1's auc: 0.795375
# Early stopping, best iteration is:
# [2155]	training's auc: 0.878024	valid_1's auc: 0.795521
# Fold  2 AUC : 0.795554
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.766545	valid_1's auc: 0.750542
# [200]	training's auc: 0.787094	valid_1's auc: 0.766056
# [300]	training's auc: 0.798658	valid_1's auc: 0.773589
# [400]	training's auc: 0.80721	valid_1's auc: 0.778146
# [500]	training's auc: 0.814151	valid_1's auc: 0.780927
# [600]	training's auc: 0.820124	valid_1's auc: 0.782821
# [700]	training's auc: 0.825467	valid_1's auc: 0.784131
# [800]	training's auc: 0.830359	valid_1's auc: 0.785139
# [900]	training's auc: 0.834861	valid_1's auc: 0.786106
# [1000]	training's auc: 0.839106	valid_1's auc: 0.786692
# [1100]	training's auc: 0.843194	valid_1's auc: 0.787317
# [1200]	training's auc: 0.847138	valid_1's auc: 0.787696
# [1300]	training's auc: 0.85082	valid_1's auc: 0.788215
# [1400]	training's auc: 0.854501	valid_1's auc: 0.788527
# [1500]	training's auc: 0.858058	valid_1's auc: 0.788664
# [1600]	training's auc: 0.861671	valid_1's auc: 0.788751
# [1700]	training's auc: 0.864932	valid_1's auc: 0.788878
# [1800]	training's auc: 0.868178	valid_1's auc: 0.788942
# [1900]	training's auc: 0.871297	valid_1's auc: 0.788961
# [2000]	training's auc: 0.874209	valid_1's auc: 0.789103
# [2100]	training's auc: 0.877249	valid_1's auc: 0.789175
# [2200]	training's auc: 0.880166	valid_1's auc: 0.789237
# [2300]	training's auc: 0.882961	valid_1's auc: 0.789205
# [2400]	training's auc: 0.885614	valid_1's auc: 0.789369
# [2500]	training's auc: 0.888367	valid_1's auc: 0.789483
# [2600]	training's auc: 0.890975	valid_1's auc: 0.78949
# [2700]	training's auc: 0.893449	valid_1's auc: 0.789512
# [2800]	training's auc: 0.895962	valid_1's auc: 0.789571
# [2900]	training's auc: 0.89836	valid_1's auc: 0.789668
# [3000]	training's auc: 0.900761	valid_1's auc: 0.789519
# [3100]	training's auc: 0.902986	valid_1's auc: 0.789578
# Early stopping, best iteration is:
# [2923]	training's auc: 0.898931	valid_1's auc: 0.789703
# Fold  3 AUC : 0.789677
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.76618	valid_1's auc: 0.755256
# [200]	training's auc: 0.78701	valid_1's auc: 0.769982
# [300]	training's auc: 0.798809	valid_1's auc: 0.776735
# [400]	training's auc: 0.807329	valid_1's auc: 0.780942
# [500]	training's auc: 0.814374	valid_1's auc: 0.783397
# [600]	training's auc: 0.820341	valid_1's auc: 0.785208
# [700]	training's auc: 0.825844	valid_1's auc: 0.786347
# [800]	training's auc: 0.83076	valid_1's auc: 0.787347
# [900]	training's auc: 0.835307	valid_1's auc: 0.788137
# [1000]	training's auc: 0.839586	valid_1's auc: 0.788654
# [1100]	training's auc: 0.843658	valid_1's auc: 0.78905
# [1200]	training's auc: 0.847585	valid_1's auc: 0.789478
# [1300]	training's auc: 0.851461	valid_1's auc: 0.789808
# [1400]	training's auc: 0.855129	valid_1's auc: 0.790154
# [1500]	training's auc: 0.858705	valid_1's auc: 0.790193
# [1600]	training's auc: 0.862187	valid_1's auc: 0.790417
# [1700]	training's auc: 0.865544	valid_1's auc: 0.790533
# [1800]	training's auc: 0.868679	valid_1's auc: 0.790791
# [1900]	training's auc: 0.871609	valid_1's auc: 0.790944
# [2000]	training's auc: 0.87466	valid_1's auc: 0.79107
# [2100]	training's auc: 0.877628	valid_1's auc: 0.791166
# [2200]	training's auc: 0.880591	valid_1's auc: 0.791253
# [2300]	training's auc: 0.8834	valid_1's auc: 0.791335
# [2400]	training's auc: 0.886054	valid_1's auc: 0.791309
# [2500]	training's auc: 0.888725	valid_1's auc: 0.791337
# Early stopping, best iteration is:
# [2367]	training's auc: 0.885212	valid_1's auc: 0.79136
# Fold  4 AUC : 0.791354
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.765379	valid_1's auc: 0.758601
# [200]	training's auc: 0.78563	valid_1's auc: 0.773737
# [300]	training's auc: 0.797349	valid_1's auc: 0.780803
# [400]	training's auc: 0.805903	valid_1's auc: 0.784893
# [500]	training's auc: 0.8132	valid_1's auc: 0.787424
# [600]	training's auc: 0.819339	valid_1's auc: 0.789038
# [700]	training's auc: 0.824844	valid_1's auc: 0.790101
# [800]	training's auc: 0.829738	valid_1's auc: 0.790866
# [900]	training's auc: 0.834279	valid_1's auc: 0.791406
# [1000]	training's auc: 0.838706	valid_1's auc: 0.792
# [1100]	training's auc: 0.842796	valid_1's auc: 0.792164
# [1200]	training's auc: 0.846685	valid_1's auc: 0.792375
# [1300]	training's auc: 0.850358	valid_1's auc: 0.792435
# [1400]	training's auc: 0.854117	valid_1's auc: 0.792612
# [1500]	training's auc: 0.857751	valid_1's auc: 0.792718
# [1600]	training's auc: 0.86106	valid_1's auc: 0.792729
# [1700]	training's auc: 0.864419	valid_1's auc: 0.792892
# [1800]	training's auc: 0.867629	valid_1's auc: 0.792943
# [1900]	training's auc: 0.870882	valid_1's auc: 0.793021
# [2000]	training's auc: 0.87396	valid_1's auc: 0.793004
# [2100]	training's auc: 0.876771	valid_1's auc: 0.79311
# [2200]	training's auc: 0.879865	valid_1's auc: 0.793087
# [2300]	training's auc: 0.882787	valid_1's auc: 0.793103
# Early stopping, best iteration is:
# [2132]	training's auc: 0.877737	valid_1's auc: 0.793196
# Fold  5 AUC : 0.793187
# Full AUC score 0.793066
# Epoch number 1 of 1 ended
# Full AUC score over all epochs 0.793066
# Run LightGBM with kfold - done in 6431s
# Full model run - done in 6473s
