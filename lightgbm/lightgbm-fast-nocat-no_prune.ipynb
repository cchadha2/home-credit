# %%
import os
import math
import time

from contextlib import contextmanager
import numpy as np
import pandas as pd
from IPython.display import display
import lightgbm
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import KFold, StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns

# %%
@contextmanager
def timer(title):
    t0 = time.time()
    yield
    print("{} - done in {:.0f}s".format(title, time.time() - t0))

# %%
def display_importances(feature_importance_df_):
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(by="importance", ascending=False)[:40].index
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]
    plt.figure(figsize=(12, 10))
    sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False))
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout()
    plt.savefig('../output/lgbm_importances_bayesian.png')

# %%
def kfold_lightgbm(df, num_folds, stratified = False, epochs = 1, corr_save = False, importance_save = False):
    df = df.drop('Unnamed: 0', axis = 1)  
    
    # Divide in training/validation and test data
    train_df = df[df['TARGET'].notnull()]
    test_df = df[df['TARGET'].isnull()]
    
    # Correlation csv processing
    if corr_save == True:
        target_corr = train_df.corr()['TARGET'].sort_values()
        corr_df = pd.DataFrame()
        corr_df['feature'] = target_corr.index
        corr_df['corr'] = target_corr.values
        corr_df = corr_df[corr_df['feature'] != 'feature']
        corr_df.to_csv('../output/correlation.csv')
        del target_corr, corr_df


    cat_cols = ['FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'FLAG_MOBIL', 'FLAG_EMP_PHONE',
                'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL',
                'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION', 'LIVE_REGION_NOT_WORK_REGION', 
                'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY',
                'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5', 'FLAG_DOCUMENT_6',
                'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_9', 'FLAG_DOCUMENT_11', 
                'FLAG_DOCUMENT_18', 'CODE_GENDER', 'NAME_CONTRACT_TYPE',
                'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY', 'EMERGENCYSTATE_MODE',
                'HOUSETYPE_MODE', 'FONDKAPREMONT_MODE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS',
                'NAME_HOUSING_TYPE', 'NAME_TYPE_SUITE', 'WALLSMATERIAL_MODE','WEEKDAY_APPR_PROCESS_START',
                'HOUR_APPR_PROCESS_START', 'NAME_INCOME_TYPE', 'OCCUPATION_TYPE', 'ORGANIZATION_TYPE']
    
    included_cat_cols = [i for i in cat_cols if i in list(train_df.columns)]
    
    # Delete variables from memory 
    del df, cat_cols

    print("Starting LightGBM. Train shape: {}, test shape: {}".format(train_df.shape, test_df.shape))
    # Initialise predictions and importance dataframes and epoch weights
    sub_df = test_df[['SK_ID_CURR']].copy()
    sub_df['TARGET'] = 0
    ep_ave = 1/epochs
    epv_preds = np.zeros(train_df.shape[0])
    feature_importance_df = pd.DataFrame()    
    
    for n in range(epochs):
        
        print('Epoch number {} of {} starting'.format(n+1, epochs))
        # Cross validation model
        if epochs == 1:
            if stratified:
                folds = StratifiedKFold(n_splits= num_folds, shuffle=True, random_state=1001)
            else:
                folds = KFold(n_splits= num_folds, shuffle=True, random_state=1001)
        else:
            if stratified:
                folds = StratifiedKFold(n_splits= num_folds, shuffle=True)
            else:
                folds = KFold(n_splits= num_folds, shuffle=True)
        # Create arrays and dataframes to store results
        oof_preds = np.zeros(train_df.shape[0])
        sub_preds = np.zeros(test_df.shape[0])
        feats = [f for f in train_df.columns if f not in ['TARGET','SK_ID_CURR','SK_ID_BUREAU','SK_ID_PREV','index']]

        for n_fold, (train_idx, valid_idx) in enumerate(folds.split(train_df[feats], train_df['TARGET'])):
            dtrain = lightgbm.Dataset(data=train_df[feats].iloc[train_idx], 
                                 label=train_df['TARGET'].iloc[train_idx], 
                                 free_raw_data=False, silent=True)#,
#                                  categorical_feature=included_cat_cols)
            dvalid = lightgbm.Dataset(data=train_df[feats].iloc[valid_idx], 
                                 label=train_df['TARGET'].iloc[valid_idx], 
                                 free_raw_data=False, silent=True)#,
#                                  categorical_feature=included_cat_cols)

            # LightGBM parameters found by Bayesian optimization
            params = {
                'objective': 'binary',
                'boosting_type': 'gbdt', # 'goss'
                'nthread': 4,
                'learning_rate': 0.02,  # 02,
                'num_leaves': 20,
                'colsample_bytree': 0.9497036,
                'subsample': 0.8715623,
                'subsample_freq': 1,
                'max_depth': 8,
                'reg_alpha': 0.041545473,
                'reg_lambda': 0.0735294,
                'min_split_gain': 0.0222415,
                'min_child_weight': 60, #39.3259775
                'seed': 0,
                'verbose': -1,
                'metric': 'auc',
            }

            clf = lightgbm.train(
                params=params,
                train_set=dtrain,
                num_boost_round=10000,
                valid_sets=[dtrain, dvalid],
                early_stopping_rounds= 200,
                verbose_eval=100
            )

            oof_preds[valid_idx] = clf.predict(dvalid.data)
            sub_preds += clf.predict(test_df[feats]) / folds.n_splits

            fold_importance_df = pd.DataFrame()
            fold_importance_df["feature"] = feats
            fold_importance_df["importance"] = clf.feature_importance(importance_type='gain')
            fold_importance_df["fold"] = n_fold + 1
            feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
            print('Fold %2d AUC : %.6f' % (n_fold + 1, roc_auc_score(dvalid.label, oof_preds[valid_idx])))
            del clf, dtrain, dvalid
            
        print('Full AUC score %.6f' % roc_auc_score(train_df['TARGET'], oof_preds))
        # Write submission file and plot feature importance
        sub_df['TARGET'] += ep_ave*sub_preds
        epv_preds += ep_ave*oof_preds
        print('Epoch number {} of {} ended'.format(n+1, epochs))
        
    sub_df[['SK_ID_CURR', 'TARGET']].to_csv(submission_file_name, index= False)
    print('Full AUC score over all epochs %.6f' % roc_auc_score(train_df['TARGET'], epv_preds))
    display_importances(feature_importance_df)
    
    # Save feature importance df as csv
    if importance_save == True:
        feature_importance_df = feature_importance_df.groupby('feature').agg('mean').drop('fold', axis = 1).sort_values('importance')
        feature_importance_df.to_csv('../output/importance_3.2.csv')

# %%
def main():
    
    df = pd.read_csv('../data/processed_data_3.2_no_prune.csv')
    
    with timer("Run LightGBM with kfold"):
        feature_importance_df = kfold_lightgbm(df,
                                               num_folds=5,
                                               stratified=False,
                                               epochs=1,
                                               corr_save=False,
                                               importance_save=False) 

if __name__ == "__main__":
    submission_file_name = "../predictions/lightgbm_pred_nocat_no_prune.csv"
    with timer("Full model run"):
        main()
# Out:
# Starting LightGBM. Train shape: (307511, 820), test shape: (48744, 820)
# Epoch number 1 of 1 starting
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.765833	valid_1's auc: 0.757673
# [200]	training's auc: 0.785807	valid_1's auc: 0.773376
# [300]	training's auc: 0.797384	valid_1's auc: 0.781126
# [400]	training's auc: 0.805764	valid_1's auc: 0.785378
# [500]	training's auc: 0.812902	valid_1's auc: 0.788244
# [600]	training's auc: 0.819056	valid_1's auc: 0.79012
# [700]	training's auc: 0.824548	valid_1's auc: 0.791269
# [800]	training's auc: 0.829345	valid_1's auc: 0.792035
# [900]	training's auc: 0.834003	valid_1's auc: 0.792587
# [1000]	training's auc: 0.838283	valid_1's auc: 0.793121
# [1100]	training's auc: 0.842469	valid_1's auc: 0.793522
# [1200]	training's auc: 0.846398	valid_1's auc: 0.793816
# [1300]	training's auc: 0.850301	valid_1's auc: 0.79413
# [1400]	training's auc: 0.853886	valid_1's auc: 0.79421
# [1500]	training's auc: 0.857419	valid_1's auc: 0.794302
# [1600]	training's auc: 0.860927	valid_1's auc: 0.794265
# [1700]	training's auc: 0.864163	valid_1's auc: 0.794421
# [1800]	training's auc: 0.867321	valid_1's auc: 0.794523
# [1900]	training's auc: 0.870472	valid_1's auc: 0.794577
# [2000]	training's auc: 0.873505	valid_1's auc: 0.794719
# [2100]	training's auc: 0.876348	valid_1's auc: 0.794634
# [2200]	training's auc: 0.879187	valid_1's auc: 0.794677
# Early stopping, best iteration is:
# [2000]	training's auc: 0.873505	valid_1's auc: 0.794719
# Fold  1 AUC : 0.794581
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.76533	valid_1's auc: 0.755136
# [200]	training's auc: 0.785645	valid_1's auc: 0.772351
# [300]	training's auc: 0.79717	valid_1's auc: 0.780069
# [400]	training's auc: 0.805629	valid_1's auc: 0.784434
# [500]	training's auc: 0.812853	valid_1's auc: 0.787228
# [600]	training's auc: 0.819053	valid_1's auc: 0.78945
# [700]	training's auc: 0.824344	valid_1's auc: 0.790501
# [800]	training's auc: 0.829252	valid_1's auc: 0.79155
# [900]	training's auc: 0.833929	valid_1's auc: 0.792379
# [1000]	training's auc: 0.838162	valid_1's auc: 0.792827
# [1100]	training's auc: 0.842337	valid_1's auc: 0.79347
# [1200]	training's auc: 0.846261	valid_1's auc: 0.793875
# [1300]	training's auc: 0.850018	valid_1's auc: 0.794116
# [1400]	training's auc: 0.853735	valid_1's auc: 0.794383
# [1500]	training's auc: 0.857166	valid_1's auc: 0.794684
# [1600]	training's auc: 0.860582	valid_1's auc: 0.794879
# [1700]	training's auc: 0.863875	valid_1's auc: 0.795034
# [1800]	training's auc: 0.867029	valid_1's auc: 0.795185
# [1900]	training's auc: 0.870122	valid_1's auc: 0.795205
# [2000]	training's auc: 0.873196	valid_1's auc: 0.795317
# [2100]	training's auc: 0.876228	valid_1's auc: 0.795338
# [2200]	training's auc: 0.879067	valid_1's auc: 0.79546
# [2300]	training's auc: 0.881952	valid_1's auc: 0.795402
# [2400]	training's auc: 0.88474	valid_1's auc: 0.795323
# Early stopping, best iteration is:
# [2205]	training's auc: 0.879208	valid_1's auc: 0.79547
# Fold  2 AUC : 0.795472
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.766723	valid_1's auc: 0.750608
# [200]	training's auc: 0.787174	valid_1's auc: 0.765876
# [300]	training's auc: 0.798921	valid_1's auc: 0.773216
# [400]	training's auc: 0.807513	valid_1's auc: 0.777873
# [500]	training's auc: 0.814341	valid_1's auc: 0.780717
# [600]	training's auc: 0.820278	valid_1's auc: 0.782659
# [700]	training's auc: 0.825613	valid_1's auc: 0.784013
# [800]	training's auc: 0.830623	valid_1's auc: 0.785147
# [900]	training's auc: 0.835205	valid_1's auc: 0.785868
# [1000]	training's auc: 0.839361	valid_1's auc: 0.786584
# [1100]	training's auc: 0.843512	valid_1's auc: 0.787264
# [1200]	training's auc: 0.847573	valid_1's auc: 0.787786
# [1300]	training's auc: 0.851308	valid_1's auc: 0.788111
# [1400]	training's auc: 0.854895	valid_1's auc: 0.788509
# [1500]	training's auc: 0.858399	valid_1's auc: 0.788763
# [1600]	training's auc: 0.861933	valid_1's auc: 0.788991
# [1700]	training's auc: 0.865228	valid_1's auc: 0.789024
# [1800]	training's auc: 0.868438	valid_1's auc: 0.789161
# [1900]	training's auc: 0.871451	valid_1's auc: 0.789258
# [2000]	training's auc: 0.874295	valid_1's auc: 0.789465
# [2100]	training's auc: 0.877355	valid_1's auc: 0.789601
# [2200]	training's auc: 0.880251	valid_1's auc: 0.789718
# [2300]	training's auc: 0.883129	valid_1's auc: 0.789692
# [2400]	training's auc: 0.885842	valid_1's auc: 0.78982
# [2500]	training's auc: 0.88845	valid_1's auc: 0.789855
# [2600]	training's auc: 0.891129	valid_1's auc: 0.789847
# [2700]	training's auc: 0.89357	valid_1's auc: 0.789846
# Early stopping, best iteration is:
# [2547]	training's auc: 0.889712	valid_1's auc: 0.789929
# Fold  3 AUC : 0.789924
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.766174	valid_1's auc: 0.755478
# [200]	training's auc: 0.787009	valid_1's auc: 0.770296
# [300]	training's auc: 0.798662	valid_1's auc: 0.77731
# [400]	training's auc: 0.807239	valid_1's auc: 0.781536
# [500]	training's auc: 0.814333	valid_1's auc: 0.784326
# [600]	training's auc: 0.820349	valid_1's auc: 0.786027
# [700]	training's auc: 0.825797	valid_1's auc: 0.787259
# [800]	training's auc: 0.83079	valid_1's auc: 0.788125
# [900]	training's auc: 0.835489	valid_1's auc: 0.788876
# [1000]	training's auc: 0.839754	valid_1's auc: 0.789506
# [1100]	training's auc: 0.843891	valid_1's auc: 0.789835
# [1200]	training's auc: 0.847842	valid_1's auc: 0.790232
# [1300]	training's auc: 0.851673	valid_1's auc: 0.790445
# [1400]	training's auc: 0.855196	valid_1's auc: 0.790798
# [1500]	training's auc: 0.858785	valid_1's auc: 0.790954
# [1600]	training's auc: 0.862281	valid_1's auc: 0.791214
# [1700]	training's auc: 0.865558	valid_1's auc: 0.791433
# [1800]	training's auc: 0.868744	valid_1's auc: 0.791608
# [1900]	training's auc: 0.871829	valid_1's auc: 0.79174
# [2000]	training's auc: 0.874908	valid_1's auc: 0.791775
# [2100]	training's auc: 0.87778	valid_1's auc: 0.791834
# [2200]	training's auc: 0.880642	valid_1's auc: 0.792008
# [2300]	training's auc: 0.883373	valid_1's auc: 0.792007
# [2400]	training's auc: 0.886089	valid_1's auc: 0.792186
# [2500]	training's auc: 0.888762	valid_1's auc: 0.792284
# [2600]	training's auc: 0.891416	valid_1's auc: 0.792245
# [2700]	training's auc: 0.893926	valid_1's auc: 0.792378
# [2800]	training's auc: 0.896428	valid_1's auc: 0.792428
# [2900]	training's auc: 0.898817	valid_1's auc: 0.792344
# Early stopping, best iteration is:
# [2770]	training's auc: 0.895731	valid_1's auc: 0.792459
# Fold  4 AUC : 0.792443
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.765677	valid_1's auc: 0.758649
# [200]	training's auc: 0.785886	valid_1's auc: 0.773516
# [300]	training's auc: 0.797463	valid_1's auc: 0.780576
# [400]	training's auc: 0.805954	valid_1's auc: 0.784651
# [500]	training's auc: 0.81326	valid_1's auc: 0.78715
# [600]	training's auc: 0.819503	valid_1's auc: 0.788731
# [700]	training's auc: 0.824894	valid_1's auc: 0.789995
# [800]	training's auc: 0.829836	valid_1's auc: 0.790787
# [900]	training's auc: 0.834398	valid_1's auc: 0.791298
# [1000]	training's auc: 0.838759	valid_1's auc: 0.791734
# [1100]	training's auc: 0.842839	valid_1's auc: 0.792031
# [1200]	training's auc: 0.846622	valid_1's auc: 0.792216
# [1300]	training's auc: 0.850452	valid_1's auc: 0.792334
# [1400]	training's auc: 0.854201	valid_1's auc: 0.792764
# [1500]	training's auc: 0.857832	valid_1's auc: 0.792918
# [1600]	training's auc: 0.861137	valid_1's auc: 0.793004
# [1700]	training's auc: 0.864463	valid_1's auc: 0.793113
# [1800]	training's auc: 0.867602	valid_1's auc: 0.793175
# [1900]	training's auc: 0.870857	valid_1's auc: 0.79333
# [2000]	training's auc: 0.873853	valid_1's auc: 0.793235
# [2100]	training's auc: 0.87676	valid_1's auc: 0.793273
# [2200]	training's auc: 0.879805	valid_1's auc: 0.79323
# [2300]	training's auc: 0.882786	valid_1's auc: 0.793173
# Early stopping, best iteration is:
# [2132]	training's auc: 0.877775	valid_1's auc: 0.793355
# Fold  5 AUC : 0.793370
# Full AUC score 0.793145
# Epoch number 1 of 1 ended
# Full AUC score over all epochs 0.793145
# Run LightGBM with kfold - done in 3241s
# Full model run - done in 3289s
