# %%
import time

from contextlib import contextmanager
import numpy as np
import pandas as pd

# %%
@contextmanager
def timer(title):
    t0 = time.time()
    yield
    print("{} - done in {:.0f}s".format(title, time.time() - t0))

# %%
def one_hot_encoder(df, nan_as_category = True):
    original_columns = list(df.columns)
    categorical_columns = [col for col in df.columns if df[col].dtype == 'object']
    df = pd.get_dummies(df, columns= categorical_columns, dummy_na= nan_as_category)
    new_columns = [c for c in df.columns if c not in original_columns]
    return df, new_columns

# %%
def application_train_and_test():
    
    application_train = pd.read_csv('../data/application_train.csv')
    application_test = pd.read_csv('../data/application_test.csv')
    
    application_train = application_train.sort_values(by = 'SK_ID_CURR')
    application_test = application_test.sort_values(by = 'SK_ID_CURR')
    df = application_train.append(application_test).reset_index()
    
    df['DAYS_EMPLOYED'].replace({365243: 1}, inplace = True)
    df['ORGANIZATION_TYPE'].replace({'XNA': np.nan}, inplace = True)
    df = df[df['CODE_GENDER'] != 'XNA']
    
    useless_features = ['FLAG_DOCUMENT_10', 'FLAG_DOCUMENT_12', 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_14', 
                        'FLAG_DOCUMENT_15', 'FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_17', 'FLAG_DOCUMENT_19', 
                        'FLAG_DOCUMENT_2', 'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21']
    
    df = df.drop(useless_features, axis = 1)
    
    df['NEW_CREDIT_TO_ANNUITY_RATIO'] = df['AMT_CREDIT'] / df['AMT_ANNUITY']
    
    # Impute missing values
    values = {'AMT_ANNUITY': (df['AMT_CREDIT']/(df['NEW_CREDIT_TO_ANNUITY_RATIO'].mean())),
             'AMT_GOODS_PRICE': df['AMT_CREDIT'], 
             'AMT_REQ_CREDIT_BUREAU_HOUR': 0,
             'AMT_REQ_CREDIT_BUREAU_DAY': 0,
             'AMT_REQ_CREDIT_BUREAU_WEEK': 0,
             'AMT_REQ_CREDIT_BUREAU_MON': 0, 
             'AMT_REQ_CREDIT_BUREAU_QRT': 0,
             'AMT_REQ_CREDIT_BUREAU_YEAR': 0,
             'APARTMENTS_AVG': df['APARTMENTS_AVG'].mean(),
             'BASEMENTAREA_AVG': df['BASEMENTAREA_AVG'].mean(),
             'YEARS_BEGINEXPLUATATION_AVG': df['YEARS_BEGINEXPLUATATION_AVG'].mean(), 
             'YEARS_BUILD_AVG': df['YEARS_BUILD_AVG'].mean(),
             'COMMONAREA_AVG': df['COMMONAREA_AVG'].mean(),
             'ELEVATORS_AVG': df['ELEVATORS_AVG'].mean(),
             'ENTRANCES_AVG': df['ENTRANCES_AVG'].mean(),
             'FLOORSMAX_AVG': df['FLOORSMAX_AVG'].mean(),
             'FLOORSMIN_AVG': df['FLOORSMIN_AVG'].mean(),
             'LANDAREA_AVG': df['LANDAREA_AVG'].mean(),
             'LIVINGAPARTMENTS_AVG': df['LIVINGAPARTMENTS_AVG'].mean(),
             'LIVINGAREA_AVG': df['LIVINGAREA_AVG'].mean(), 
             'NONLIVINGAPARTMENTS_AVG': df['NONLIVINGAPARTMENTS_AVG'].mean(),
             'NONLIVINGAREA_AVG': df['NONLIVINGAREA_AVG'].mean(),
             'APARTMENTS_MODE': df['APARTMENTS_MODE'].mode()[0],
             'BASEMENTAREA_MODE': df['BASEMENTAREA_MODE'].mode()[0],
             'YEARS_BEGINEXPLUATATION_MODE': df['YEARS_BEGINEXPLUATATION_MODE'].mode()[0],
             'YEARS_BUILD_MODE': df['YEARS_BUILD_MODE'].mode()[0],
             'COMMONAREA_MODE': df['COMMONAREA_MODE'].mode()[0],
             'ELEVATORS_MODE': df['ELEVATORS_MODE'].mode()[0],
             'ENTRANCES_MODE': df['ENTRANCES_MODE'].mode()[0],
             'FLOORSMAX_MODE': df['FLOORSMAX_MODE'].mode()[0],
             'FLOORSMIN_MODE': df['FLOORSMIN_MODE'].mode()[0],
             'LANDAREA_MODE': df['LANDAREA_MODE'].mode()[0],
             'LIVINGAPARTMENTS_MODE': df['LIVINGAPARTMENTS_MODE'].mode()[0],
             'LIVINGAREA_MODE': df['LIVINGAREA_MODE'].mode()[0],
             'NONLIVINGAPARTMENTS_MODE': df['NONLIVINGAPARTMENTS_MODE'].mode()[0],
             'NONLIVINGAREA_MODE': df['NONLIVINGAREA_MODE'].mode()[0],
             'FONDKAPREMONT_MODE': df['FONDKAPREMONT_MODE'].mode()[0],
             'HOUSETYPE_MODE': df['HOUSETYPE_MODE'].mode()[0],
             'TOTALAREA_MODE': df['TOTALAREA_MODE'].mode()[0],
             'WALLSMATERIAL_MODE': df['WALLSMATERIAL_MODE'].mode()[0],
             'EMERGENCYSTATE_MODE': df['EMERGENCYSTATE_MODE'].mode()[0],
             'APARTMENTS_MEDI': df['APARTMENTS_MEDI'].median(),
             'BASEMENTAREA_MEDI': df['BASEMENTAREA_MEDI'].median(),
             'YEARS_BEGINEXPLUATATION_MEDI': df['YEARS_BEGINEXPLUATATION_MEDI'].median(),
             'YEARS_BUILD_MEDI': df['YEARS_BUILD_MEDI'].median(),
             'COMMONAREA_MEDI': df['COMMONAREA_MEDI'].median(),
             'ELEVATORS_MEDI': df['ELEVATORS_MEDI'].median(),
             'ENTRANCES_MEDI': df['ENTRANCES_MEDI'].median(),
             'FLOORSMAX_MEDI': df['FLOORSMAX_MEDI'].median(),
             'FLOORSMIN_MEDI': df['FLOORSMIN_MEDI'].median(),
             'LANDAREA_MEDI': df['LANDAREA_MEDI'].median(),
             'LIVINGAREA_MEDI': df['LIVINGAREA_MEDI'].median(),
             'LIVINGAPARTMENTS_MEDI': df['LIVINGAPARTMENTS_MEDI'].median(),
             'NONLIVINGAPARTMENTS_MEDI': df['NONLIVINGAPARTMENTS_MEDI'].median(),
             'NONLIVINGAREA_MEDI': df['NONLIVINGAREA_MEDI'].median(), 
             'CNT_FAM_MEMBERS': 0, 
             'DAYS_EMPLOYED': 1,
             'DAYS_LAST_PHONE_CHANGE': 0, 
             'DEF_30_CNT_SOCIAL_CIRCLE': 0,
             'DEF_60_CNT_SOCIAL_CIRCLE': 0,
             'OBS_30_CNT_SOCIAL_CIRCLE': 0,
             'OBS_60_CNT_SOCIAL_CIRCLE': 0,
             'CNT_FAM_MEMBERS': 0
             }
    
    
    df = df.fillna(value=values)
    
    with timer('EXT_SOURCE processing ran'):
        for t, row in df.iterrows():
            if np.isnan(row['EXT_SOURCE_1']):
                if np.isnan(row['EXT_SOURCE_2']) and np.isnan(row['EXT_SOURCE_3']):
                    df['EXT_SOURCE_1'][t] = (df['EXT_SOURCE_2'][t]+df['EXT_SOURCE_3'][t])/2
                if np.isnan(row['EXT_SOURCE_2']) and np.isnan(row['EXT_SOURCE_3']):
                    df['EXT_SOURCE_1'][t] = df['EXT_SOURCE_3'][t]
                if np.isnan(row['EXT_SOURCE_2']) and np.isnan(row['EXT_SOURCE_3']):
                    df['EXT_SOURCE_1'][t] = df['EXT_SOURCE_2'][t]
                else:
                    df['EXT_SOURCE_1'][t] = df['EXT_SOURCE_1'].median()
            if np.isnan(row['EXT_SOURCE_2']):
                if np.isnan(row['EXT_SOURCE_1']) and np.isnan(row['EXT_SOURCE_3']):
                    df['EXT_SOURCE_2'][t] = (df['EXT_SOURCE_1'][t]+df['EXT_SOURCE_3'][t])/2
                if np.isnan(row['EXT_SOURCE_1']) and np.isnan(row['EXT_SOURCE_3']):
                    df['EXT_SOURCE_2'][t] = df['EXT_SOURCE_3'][t]
                if np.isnan(row['EXT_SOURCE_1']) and np.isnan(row['EXT_SOURCE_3']):
                    df['EXT_SOURCE_2'][t] = df['EXT_SOURCE_1'][t]
                else:
                    df['EXT_SOURCE_2'][t] = df['EXT_SOURCE_2'].median()
            if np.isnan(row['EXT_SOURCE_3']):
                if np.isnan(row['EXT_SOURCE_2']) and np.isnan(row['EXT_SOURCE_1']):
                    df['EXT_SOURCE_3'][t] = (df['EXT_SOURCE_2'][t]+df['EXT_SOURCE_1'][t])/2
                if np.isnan(row['EXT_SOURCE_2']) and np.isnan(row['EXT_SOURCE_1']):
                    df['EXT_SOURCE_3'][t] = df['EXT_SOURCE_1'][t]
                if np.isnan(row['EXT_SOURCE_2']) and np.isnan(row['EXT_SOURCE_1']):
                    df['EXT_SOURCE_3'][t] = df['EXT_SOURCE_2'][t]
                else:
                    df['EXT_SOURCE_3'][t] = df['EXT_SOURCE_3'].median()
            if np.isnan(row['EXT_SOURCE_1']) and np.isnan(row['EXT_SOURCE_2']) and np.isnan(row['EXT_SOURCE_3']):
                df['EXT_SOURCE_1'][t] = 0
                df['EXT_SOURCE_2'][t] = 0
                df['EXT_SOURCE_3'][t] = 0
 
    
    docs = [_f for _f in df.columns if 'FLAG_DOC' in _f]
    live = [_f for _f in df.columns if ('FLAG_' in _f) & ('FLAG_DOC' not in _f) & ('_FLAG_' not in _f)]
    
    inc_by_org = df[['AMT_INCOME_TOTAL', 'ORGANIZATION_TYPE']].groupby('ORGANIZATION_TYPE').median()['AMT_INCOME_TOTAL']

    df['NEW_CREDIT_TO_GOODS_RATIO'] = df['AMT_CREDIT'] / df['AMT_GOODS_PRICE']
    df['NEW_DOC_IND_AVG'] = df[docs].mean(axis=1)
    df['NEW_DOC_IND_STD'] = df[docs].std(axis=1)
    df['NEW_DOC_IND_KURT'] = df[docs].kurtosis(axis=1)
    df['NEW_LIVE_IND_SUM'] = df[live].sum(axis=1)
    df['NEW_LIVE_IND_STD'] = df[live].std(axis=1)
    df['NEW_LIVE_IND_KURT'] = df[live].kurtosis(axis=1)
    df['NEW_INC_PER_CHLD'] = df['AMT_INCOME_TOTAL'] / (1 + df['CNT_CHILDREN'])
    df['NEW_INC_BY_ORG'] = df['ORGANIZATION_TYPE'].map(inc_by_org)
    df['NEW_ANNUITY_TO_INCOME_RATIO'] = df['AMT_ANNUITY'] / (1 + df['AMT_INCOME_TOTAL'])
    df['NEW_SOURCES_PROD'] = df['EXT_SOURCE_1'] * df['EXT_SOURCE_2'] * df['EXT_SOURCE_3']
    df['NEW_EXT_SOURCES_MEAN'] = df[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']].mean(axis=1)
    df['NEW_SCORES_STD'] = df[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']].std(axis=1)
    df['NEW_SCORES_STD'] = df['NEW_SCORES_STD'].fillna(df['NEW_SCORES_STD'].mean())
    df['NEW_CAR_TO_BIRTH_RATIO'] = df['OWN_CAR_AGE'] / df['DAYS_BIRTH']
    df['NEW_CAR_TO_EMPLOY_RATIO'] = df['OWN_CAR_AGE'] / df['DAYS_EMPLOYED']
    df['NEW_PHONE_TO_BIRTH_RATIO'] = df['DAYS_LAST_PHONE_CHANGE'] / df['DAYS_BIRTH']
    df['NEW_PHONE_TO_EMPLOY_RATIO'] = df['DAYS_LAST_PHONE_CHANGE'] / df['DAYS_EMPLOYED']
    df['NEW_EMPLOY_TO_BIRTH_RATIO'] = df['DAYS_EMPLOYED'] / df['DAYS_BIRTH']
    df['DAYS_EMPLOYED_PERC'] = df['DAYS_EMPLOYED'] / df['DAYS_BIRTH']
    df['INCOME_CREDIT_PERC'] = df['AMT_INCOME_TOTAL'] / df['AMT_CREDIT']
    df['INCOME_PER_PERSON'] = df['AMT_INCOME_TOTAL'] / df['CNT_FAM_MEMBERS']
    df['ANNUITY_INCOME_PERC'] = df['AMT_ANNUITY'] / df['AMT_INCOME_TOTAL']
    df['PAYMENT_RATE'] = df['AMT_ANNUITY'] / df['AMT_CREDIT']
    df['NEW_CREDIT_TO_ANNUITY_RATIO'] = df['AMT_CREDIT'] / df['AMT_ANNUITY']
            
    # Feature interactions
    df['EXT_SOURCE_1_1'] = df['EXT_SOURCE_1']**2
    df['EXT_SOURCE_1_2'] = df['EXT_SOURCE_1'] * df['EXT_SOURCE_2']
    df['EXT_SOURCE_1_3'] = df['EXT_SOURCE_1'] * df['EXT_SOURCE_3']
    df['EXT_SOURCE_1_DAYS_BIRTH'] = df['EXT_SOURCE_1'] * df['DAYS_BIRTH']
    df['EXT_SOURCE_2_2'] = df['EXT_SOURCE_2']**2
    df['EXT_SOURCE_2_3'] = df['EXT_SOURCE_2'] * df['EXT_SOURCE_3']
    df['EXT_SOURCE_2_DAYS_BIRTH'] = df['EXT_SOURCE_2'] * df['DAYS_BIRTH']
    df['EXT_SOURCE_3_3'] = df['EXT_SOURCE_3']**2
    df['EXT_SOURCE_3_DAYS_BIRTH'] = df['EXT_SOURCE_3'] * df['DAYS_BIRTH']
    df['DAYS_BIRTH_DAYS_BIRTH'] = df['DAYS_BIRTH']**2
    df['DAYS_EMPLOYED_DAYS_BIRTH'] = df['DAYS_EMPLOYED'] * df['DAYS_BIRTH']
    df['DAYS_EMPLOYED_DAYS_EMPLOYED'] = df['DAYS_EMPLOYED']**2
    df['AMT_CREDIT_AMT_ANNUITY'] = df['AMT_CREDIT'] * df['AMT_ANNUITY']
    df['AMT_CREDIT_AMT_CREDIT'] = df['AMT_CREDIT']**2
    df['AMT_ANNUITY_AMT_ANNUITY'] = df['AMT_ANNUITY']**2
    
    categorical_features = ['FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'FLAG_MOBIL', 'FLAG_EMP_PHONE',
                            'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL',
                            'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION', 'LIVE_REGION_NOT_WORK_REGION', 
                            'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY',
                            'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5', 'FLAG_DOCUMENT_6',
                            'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_9', 'FLAG_DOCUMENT_11', 
                            'FLAG_DOCUMENT_18', 'CODE_GENDER', 'NAME_CONTRACT_TYPE',
                            'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY', 'EMERGENCYSTATE_MODE',
                            'HOUSETYPE_MODE', 'FONDKAPREMONT_MODE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS',
                            'NAME_HOUSING_TYPE', 'NAME_TYPE_SUITE', 'WALLSMATERIAL_MODE','WEEKDAY_APPR_PROCESS_START',
                            'NAME_INCOME_TYPE', 'OCCUPATION_TYPE', 'ORGANIZATION_TYPE']
    
    for feature in categorical_features:
        df[feature], uniques = pd.factorize(df[feature])
    
    df = df.drop('index', axis=1)
    
    del application_train
    del application_test
    
    return df

# %%
def bureau_and_balance(df):
    
    bureau = pd.read_csv('../data/bureau.csv')
    bureau_balance = pd.read_csv('../data/bureau_balance.csv')
    
    previous_loans = bureau.groupby('SK_ID_CURR', as_index=False)['SK_ID_BUREAU'].count().rename(columns = {'SK_ID_BUREAU': 'previous_loans'})
    df = df.merge(previous_loans, on = 'SK_ID_CURR', how = 'left')
    df['previous_loans'] = df['previous_loans'].fillna(0)
    
    closed_loans = bureau[bureau['CREDIT_ACTIVE'] == 'Closed']
    closed_loans = closed_loans.groupby('SK_ID_CURR', as_index=False)['CREDIT_ACTIVE'].count().rename(columns = {'CREDIT_ACTIVE': 'closed_loans'})
    df = df.merge(closed_loans, on = 'SK_ID_CURR', how = 'left')
    df['closed_loans'] = df['closed_loans'].fillna(0)
    active_loans = bureau[bureau['CREDIT_ACTIVE'] == 'Active']
    active_loans = active_loans.groupby('SK_ID_CURR', as_index=False)['CREDIT_ACTIVE'].count().rename(columns = {'CREDIT_ACTIVE': 'active_loans'})
    df = df.merge(active_loans, on = 'SK_ID_CURR', how = 'left')
    df['active_loans'] = df['active_loans'].fillna(0)
        
    bureau, bureau_cat_cols = one_hot_encoder(bureau)
    bureau_balance, bureau_balance_cat_cols = one_hot_encoder(bureau_balance)    

    bureau_aggregations = {'DAYS_CREDIT':['min', 'max', 'mean', 'var'],
                           'CREDIT_DAY_OVERDUE':['max', 'mean'],
                           'DAYS_CREDIT_ENDDATE': ['min', 'max', 'mean'],
                           'DAYS_ENDDATE_FACT': ['mean'],
                           'AMT_CREDIT_MAX_OVERDUE': ['mean'],
                           'CNT_CREDIT_PROLONG': ['count', 'sum'],
                           'AMT_CREDIT_SUM': ['min', 'max', 'mean'],
                           'AMT_CREDIT_SUM_DEBT': ['min', 'max', 'mean'],
                           'AMT_CREDIT_SUM_LIMIT': ['sum', 'mean'],
                           'AMT_CREDIT_SUM_OVERDUE': ['mean'],
                           'DAYS_CREDIT_UPDATE': ['min', 'max', 'mean'],
                           'AMT_ANNUITY': ['max', 'mean'],
                           'MONTHS_BALANCE_MIN': ['min'],
                           'MONTHS_BALANCE_MAX': ['max'],
                           'MONTHS_BALANCE_SIZE': ['mean', 'sum']}

    bureau_balance_aggregations = {'MONTHS_BALANCE': ['min', 'max', 'size']}
    
    for col in bureau_cat_cols:
        bureau_aggregations[col] = ['mean']
    for col in bureau_balance_cat_cols:
        bureau_balance_aggregations[col] = ['mean']
        
    bureau_balance_aggregations = bureau_balance.groupby('SK_ID_BUREAU').agg(bureau_balance_aggregations)
    bureau_balance_aggregations.columns = pd.Index([e[0] + "_" + e[1].upper() for e in bureau_balance_aggregations.columns.tolist()])
    bureau = bureau.join(bureau_balance_aggregations, how='left', on='SK_ID_BUREAU')
    bureau.drop(['SK_ID_BUREAU'], axis=1, inplace= True)
        
    bureau_agg = bureau.groupby('SK_ID_CURR').agg(bureau_aggregations)
    bureau_agg.columns = pd.Index(['BURO_' + e[0] + "_" + e[1].upper() for e in bureau_agg.columns.tolist()])
    
    active = bureau[bureau['CREDIT_ACTIVE_Active'] == 1]
    active_agg = active.groupby('SK_ID_CURR').agg(bureau_aggregations)
    cols = active_agg.columns.tolist()
    active_agg.columns = pd.Index(['ACTIVE_' + e[0] + "_" + e[1].upper() for e in active_agg.columns.tolist()])
    bureau_agg = bureau_agg.join(active_agg, how='left', on='SK_ID_CURR')
    del active, active_agg
    
    closed = bureau[bureau['CREDIT_ACTIVE_Closed'] == 1]
    closed_agg = closed.groupby('SK_ID_CURR').agg(bureau_aggregations)
    closed_agg.columns = pd.Index(['CLOSED_' + e[0] + "_" + e[1].upper() for e in closed_agg.columns.tolist()])
    bureau_agg = bureau_agg.join(closed_agg, how='left', on='SK_ID_CURR')
    
    for e in cols:
        bureau_agg['NEW_RATIO_BURO_' + e[0] + "_" + e[1].upper()] = bureau_agg['ACTIVE_' + e[0] + "_" + e[1].upper()] / bureau_agg['CLOSED_' + e[0] + "_" + e[1].upper()]
    
    df = df.merge(bureau_agg, on = 'SK_ID_CURR', how = 'left')
            
    del bureau
    del bureau_balance
    del bureau_balance_aggregations
    del bureau_agg
    del previous_loans
    del closed_loans
    del active_loans
    del closed
    del closed_agg
    
    return df

# %%
def cc_balance(df):
    
    credit_card_balance = pd.read_csv('../data/credit_card_balance.csv')
    
    current_loan_status = credit_card_balance[['SK_ID_CURR', 'SK_ID_PREV', 'NAME_CONTRACT_STATUS']].sort_values(by = ['SK_ID_CURR', 'NAME_CONTRACT_STATUS']).drop_duplicates()
    current_loan_status = current_loan_status[current_loan_status['NAME_CONTRACT_STATUS'].isin(['Active', 'Completed'])]
    
    prev_credit_completed = current_loan_status[current_loan_status['NAME_CONTRACT_STATUS'] == 'Completed']
    prev_credit_completed = pd.get_dummies(prev_credit_completed)
    del prev_credit_completed['SK_ID_PREV']
    prev_credit_completed = prev_credit_completed.groupby('SK_ID_CURR', as_index=False)['NAME_CONTRACT_STATUS_Completed'].count()
    df = df.merge(prev_credit_completed, on = 'SK_ID_CURR', how = 'left')
    df['NAME_CONTRACT_STATUS_Completed'] = df['NAME_CONTRACT_STATUS_Completed'].fillna(0)
    
    prev_credit_active = current_loan_status.drop_duplicates(subset = ['SK_ID_CURR', 'SK_ID_PREV'], keep = False)
    prev_credit_active = prev_credit_active[prev_credit_active['NAME_CONTRACT_STATUS'] == 'Active']
    prev_credit_active = pd.get_dummies(prev_credit_active)
    del prev_credit_active['SK_ID_PREV']
    prev_credit_active = prev_credit_active.groupby('SK_ID_CURR', as_index=False)['NAME_CONTRACT_STATUS_Active'].count()
    df = df.merge(prev_credit_active, on = 'SK_ID_CURR', how = 'left')
    df['NAME_CONTRACT_STATUS_Active'] = df['NAME_CONTRACT_STATUS_Active'].fillna(0)
        
    credit_card_balance.drop(columns = ['NAME_CONTRACT_STATUS', 'SK_ID_PREV'], inplace = True)
    
    cc_agg = credit_card_balance.groupby('SK_ID_CURR').agg(['min', 'max', 'mean', 'sum', 'var'])
    cc_agg.columns = pd.Index(['CC_' + e[0] + "_" + e[1].upper() for e in cc_agg.columns.tolist()])
    cc_agg['CC_COUNT'] = credit_card_balance.groupby('SK_ID_CURR').size()
    
    df = df.merge(cc_agg, on = 'SK_ID_CURR', how = 'left')
    df['CC_COUNT'] = df['CC_COUNT'].fillna(0)
    
    del credit_card_balance
    del current_loan_status
    del prev_credit_completed
    del prev_credit_active
    del cc_agg
    
    return df

# %%
def installments(df):
    
    ins = pd.read_csv('../data/installments_payments.csv')

    ins['INSTALLMENTS_DAY_DIFF'] = ins['DAYS_INSTALMENT'] - ins['DAYS_ENTRY_PAYMENT']
    ins['INSTALLMENTS_DIFF'] = ins['AMT_INSTALMENT'] - ins['AMT_PAYMENT']
    ins['PAYMENT_PERC'] = ins['AMT_PAYMENT'] / ins['AMT_INSTALMENT']
    ins['DPD'] = ins['DAYS_ENTRY_PAYMENT'] - ins['DAYS_INSTALMENT']
    ins['DBD'] = ins['DAYS_INSTALMENT'] - ins['DAYS_ENTRY_PAYMENT']
    ins['DPD'] = ins['DPD'].apply(lambda x: x if x > 0 else 0)
    ins['DBD'] = ins['DBD'].apply(lambda x: x if x > 0 else 0)
    
    # Feature interactions
    ins['INSTALLMENTS_DIFF_INSTALLMENTS_DAY_DIFF'] = ins['INSTALLMENTS_DIFF'] * ins['INSTALLMENTS_DAY_DIFF']
    ins['INSTALLMENTS_DIFF_INSTALLMENTS_DIFF'] = ins['INSTALLMENTS_DIFF']**2
    ins['INSTALLMENTS_DAY_DIFF_INSTALLMENTS_DAY_DIFF'] = ins['INSTALLMENTS_DAY_DIFF']**2
    
    aggregations = {
        'NUM_INSTALMENT_VERSION': ['nunique'],
        'DPD': ['max', 'mean', 'sum'],
        'DBD': ['max', 'mean', 'sum'],
        'PAYMENT_PERC': ['max', 'mean', 'sum', 'var'],
        'AMT_INSTALMENT': ['max', 'mean', 'sum'],
        'AMT_PAYMENT': ['min', 'max', 'mean', 'sum'],
        'DAYS_ENTRY_PAYMENT': ['max', 'mean', 'sum'], 
        'INSTALLMENTS_DAY_DIFF': ['max', 'mean', 'sum', 'var'], 
        'INSTALLMENTS_DIFF': ['max', 'mean', 'sum', 'var'], 
        'INSTALLMENTS_DIFF_INSTALLMENTS_DAY_DIFF': ['max', 'mean', 'sum', 'var'], 
        'INSTALLMENTS_DIFF_INSTALLMENTS_DIFF': ['max', 'mean', 'sum', 'var'], 
        'INSTALLMENTS_DAY_DIFF_INSTALLMENTS_DAY_DIFF': ['max', 'mean', 'sum', 'var']
    }
    
    ins_agg = ins.groupby('SK_ID_CURR').agg(aggregations)
    ins_agg.columns = pd.Index(['INSTAL_' + e[0] + "_" + e[1].upper() for e in ins_agg.columns.tolist()])
    # Count installments accounts
    ins_agg['INSTAL_COUNT'] = ins.groupby('SK_ID_CURR').size()
    
    df = df.merge(ins_agg, on = 'SK_ID_CURR', how = 'left')
    
    del ins
    del ins_agg
    
    return df

# %%
def pos_cash(df):
    
    POS_CASH_balance = pd.read_csv('../data/POS_CASH_balance.csv')

    current_POS_status = POS_CASH_balance[['SK_ID_CURR', 'SK_ID_PREV', 'NAME_CONTRACT_STATUS']].sort_values(by = ['SK_ID_CURR', 'NAME_CONTRACT_STATUS']).drop_duplicates()
    current_POS_status = current_POS_status[current_POS_status['NAME_CONTRACT_STATUS'].isin(['Active', 'Completed'])]

    prev_POS_completed = current_POS_status[current_POS_status['NAME_CONTRACT_STATUS'] == 'Completed']
    prev_POS_completed = pd.get_dummies(prev_POS_completed)
    del prev_POS_completed['SK_ID_PREV']
    prev_POS_completed = prev_POS_completed.rename(columns = {'NAME_CONTRACT_STATUS_Completed': 'NAME_CONTRACT_STATUS_Completed_POS'})
    prev_POS_completed = prev_POS_completed.groupby('SK_ID_CURR', as_index=False)['NAME_CONTRACT_STATUS_Completed_POS'].count()
    df = df.merge(prev_POS_completed, on = 'SK_ID_CURR', how = 'left')
    df['NAME_CONTRACT_STATUS_Completed_POS'] = df['NAME_CONTRACT_STATUS_Completed_POS'].fillna(0)

    prev_POS_active = current_POS_status.drop_duplicates(subset = ['SK_ID_CURR', 'SK_ID_PREV'], keep = False)
    prev_POS_active = prev_POS_active[prev_POS_active['NAME_CONTRACT_STATUS'] == 'Active']
    prev_POS_active = pd.get_dummies(prev_POS_active)
    del prev_POS_active['SK_ID_PREV']
    prev_POS_active = prev_POS_active.rename(columns = {'NAME_CONTRACT_STATUS_Active': 'NAME_CONTRACT_STATUS_Active_POS'})
    prev_POS_active = prev_POS_active.groupby('SK_ID_CURR', as_index=False)['NAME_CONTRACT_STATUS_Active_POS'].count()
    df = df.merge(prev_POS_active, on = 'SK_ID_CURR', how = 'left')
    df['NAME_CONTRACT_STATUS_Active_POS'] = df['NAME_CONTRACT_STATUS_Active_POS'].fillna(0)
    
    aggregations = {
        'MONTHS_BALANCE': ['max', 'mean', 'size'],
        'SK_DPD': ['max', 'mean'],
        'SK_DPD_DEF': ['max', 'mean'], 
        'CNT_INSTALMENT': ['min', 'max', 'mean'],
        'CNT_INSTALMENT_FUTURE': ['min', 'max', 'mean']
    }

    POS_CASH_balance.drop(columns = ['NAME_CONTRACT_STATUS', 'SK_ID_PREV'], inplace = True) 
    POS_CASH_balance_agg = POS_CASH_balance.groupby('SK_ID_CURR').agg(aggregations)
    POS_CASH_balance_agg.columns = pd.Index(['POS_' + e[0] + "_" + e[1].upper() for e in POS_CASH_balance_agg.columns.tolist()])
    POS_CASH_balance_agg['POS_COUNT'] = POS_CASH_balance.groupby('SK_ID_CURR').size()
    
    df = df.merge(POS_CASH_balance_agg, on = 'SK_ID_CURR', how = 'left')
    
    del current_POS_status
    del prev_POS_completed
    del prev_POS_active
    del POS_CASH_balance
    del POS_CASH_balance_agg
    
    return df

# %%
def prev_app(df):

    previous_application = pd.read_csv('../data/previous_application.csv')

    previous_application['DAYS_FIRST_DRAWING'].replace(365243, np.nan, inplace= True)
    previous_application['DAYS_FIRST_DUE'].replace(365243, np.nan, inplace= True)
    previous_application['DAYS_LAST_DUE_1ST_VERSION'].replace(365243, np.nan, inplace= True)
    previous_application['DAYS_LAST_DUE'].replace(365243, np.nan, inplace= True)
    previous_application['DAYS_TERMINATION'].replace(365243, np.nan, inplace= True)
    previous_application['APP_CREDIT_PERC'] = previous_application['AMT_APPLICATION'] / previous_application['AMT_CREDIT']
    
    previous_application, cat_cols = one_hot_encoder(previous_application)
    
    num_aggregations = {
        'AMT_ANNUITY': ['min', 'max', 'mean'],
        'AMT_APPLICATION': ['min', 'max', 'mean'],
        'AMT_CREDIT': ['min', 'max', 'mean'],
        'APP_CREDIT_PERC': ['min', 'max', 'mean', 'var'],
        'AMT_DOWN_PAYMENT': ['min', 'max', 'mean'],
        'AMT_GOODS_PRICE': ['min', 'max', 'mean'],
        'HOUR_APPR_PROCESS_START': ['min', 'max', 'mean'],
        'RATE_DOWN_PAYMENT': ['min', 'max', 'mean'],
        'DAYS_DECISION': ['min', 'max', 'mean'],
        'CNT_PAYMENT': ['mean', 'sum'],
    }
    cat_aggregations = {}
    for cat in cat_cols:
        cat_aggregations[cat] = ['mean']

    prev_agg = previous_application.groupby('SK_ID_CURR').agg({**num_aggregations, **cat_aggregations})
    prev_agg.columns = pd.Index(['PREV_' + e[0] + "_" + e[1].upper() for e in prev_agg.columns.tolist()])

    approved = previous_application[previous_application['NAME_CONTRACT_STATUS_Approved'] == 1]
    approved_agg = approved.groupby('SK_ID_CURR').agg(num_aggregations)
    cols = approved_agg.columns.tolist()
    approved_agg.columns = pd.Index(['APPROVED_' + e[0] + "_" + e[1].upper() for e in approved_agg.columns.tolist()])
    prev_agg = prev_agg.join(approved_agg, how='left', on='SK_ID_CURR')

    refused = previous_application[previous_application['NAME_CONTRACT_STATUS_Refused'] == 1]
    refused_agg = refused.groupby('SK_ID_CURR').agg(num_aggregations)
    refused_agg.columns = pd.Index(['REFUSED_' + e[0] + "_" + e[1].upper() for e in refused_agg.columns.tolist()])
    prev_agg = prev_agg.join(refused_agg, how='left', on='SK_ID_CURR')
    
    for e in cols:
        prev_agg['NEW_RATIO_PREV_' + e[0] + "_" + e[1].upper()] = prev_agg['APPROVED_' + e[0] + "_" + e[1].upper()] / prev_agg['REFUSED_' + e[0] + "_" + e[1].upper()]
    

    df = df.merge(prev_agg, on = 'SK_ID_CURR', how = 'left')
    
    del previous_application
    del prev_agg
    del approved
    del approved_agg
    del refused
    del refused_agg
    
    return df

# %%
def main():
    with timer("Process application_train and _test:"):
        df = application_train_and_test()
        print("df shape:", df.shape)
    with timer("Process bureau and bureau_balance"):
        df = bureau_and_balance(df)
        print("df shape:", df.shape)
    with timer("Process credit card balance"):
        df = cc_balance(df)
        print("df shape:", df.shape)
    with timer("Process installments payments"):
        df = installments(df)
        print("df shape:", df.shape)
    with timer("Process POS_CASH_balance"):
        df = pos_cash(df)
        print("df shape:", df.shape)
    with timer("Process previous_applications"):
        df = prev_app(df)
        print("df shape:", df.shape)
        
    return df      

if __name__ == "__main__":
    with timer("Processing pipeline run"):
        df = main()
        
        # Remove all features that weren't split on at least twice in most recent run
        importance = pd.read_csv('../output/importance.csv')
        importance_red = importance[importance['importance']<=2]
        importance_red.reset_index(inplace = True)
        for row in range(len(importance_red) -1):
            df = df.drop(importance_red['feature'][row], axis = 1)
            
        # Save processed data to csv    
        df.to_csv('../data/processed_data_3.0.csv')
# Out:
# /anaconda3/envs/home-credit/lib/python3.6/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# /anaconda3/envs/home-credit/lib/python3.6/site-packages/ipykernel_launcher.py:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/home-credit/lib/python3.6/site-packages/ipykernel_launcher.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/home-credit/lib/python3.6/site-packages/ipykernel_launcher.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/home-credit/lib/python3.6/site-packages/ipykernel_launcher.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/home-credit/lib/python3.6/site-packages/ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/home-credit/lib/python3.6/site-packages/ipykernel_launcher.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/home-credit/lib/python3.6/site-packages/ipykernel_launcher.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/home-credit/lib/python3.6/site-packages/ipykernel_launcher.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/home-credit/lib/python3.6/site-packages/ipykernel_launcher.py:108: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/home-credit/lib/python3.6/site-packages/ipykernel_launcher.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/home-credit/lib/python3.6/site-packages/ipykernel_launcher.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/home-credit/lib/python3.6/site-packages/ipykernel_launcher.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/home-credit/lib/python3.6/site-packages/ipykernel_launcher.py:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/home-credit/lib/python3.6/site-packages/ipykernel_launcher.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/home-credit/lib/python3.6/site-packages/ipykernel_launcher.py:123: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# EXT_SOURCE processing ran - done in 9923s
# df shape: (356251, 150)
# Process application_train and _test: - done in 9951s
# df shape: (356251, 381)
# Process bureau and bureau_balance - done in 53s
# df shape: (356251, 484)
# Process credit card balance - done in 31s
# df shape: (356251, 526)
# Process installments payments - done in 39s
# df shape: (356251, 542)
# Process POS_CASH_balance - done in 25s
# df shape: (356251, 821)
# Process previous_applications - done in 58s
# Processing pipeline run - done in 10824s

# %%
def missing_value_counter(DataFrame):
    print('The following features are missing values: \n')
    total_missing = 0
    for column in DataFrame.columns:
        if DataFrame[column].isnull().values.any():
            no_missing = DataFrame[column].isna().value_counts()[1]
            total_missing += no_missing
            print('{} missing value counts: {}, {:.5f}% of column missing'.format(column, no_missing, no_missing/len(DataFrame[column])))
            
    return total_missing

# %%
total_missing = missing_value_counter(df)
# Out:
# The following features are missing values:
#
# OWN_CAR_AGE missing value counts: 235239, 0.66032% of column missing
# TARGET missing value counts: 48744, 0.13682% of column missing
# NEW_CREDIT_TO_ANNUITY_RATIO missing value counts: 36, 0.00010% of column missing
# NEW_INC_BY_ORG missing value counts: 64648, 0.18147% of column missing
# NEW_CAR_TO_BIRTH_RATIO missing value counts: 235239, 0.66032% of column missing
# NEW_CAR_TO_EMPLOY_RATIO missing value counts: 235239, 0.66032% of column missing
# NEW_PHONE_TO_EMPLOY_RATIO missing value counts: 1, 0.00000% of column missing
# BURO_DAYS_CREDIT_MIN missing value counts: 50444, 0.14160% of column missing
# BURO_DAYS_CREDIT_MAX missing value counts: 50444, 0.14160% of column missing
# BURO_DAYS_CREDIT_MEAN missing value counts: 50444, 0.14160% of column missing
# BURO_DAYS_CREDIT_VAR missing value counts: 91964, 0.25814% of column missing
# BURO_CREDIT_DAY_OVERDUE_MAX missing value counts: 50444, 0.14160% of column missing
# BURO_CREDIT_DAY_OVERDUE_MEAN missing value counts: 50444, 0.14160% of column missing
# BURO_DAYS_CREDIT_ENDDATE_MIN missing value counts: 53029, 0.14885% of column missing
# BURO_DAYS_CREDIT_ENDDATE_MAX missing value counts: 53029, 0.14885% of column missing
# BURO_DAYS_CREDIT_ENDDATE_MEAN missing value counts: 53029, 0.14885% of column missing
# BURO_DAYS_ENDDATE_FACT_MEAN missing value counts: 88100, 0.24730% of column missing
# BURO_AMT_CREDIT_MAX_OVERDUE_MEAN missing value counts: 143284, 0.40220% of column missing
# BURO_CNT_CREDIT_PROLONG_COUNT missing value counts: 50444, 0.14160% of column missing
# BURO_CNT_CREDIT_PROLONG_SUM missing value counts: 50444, 0.14160% of column missing
# BURO_AMT_CREDIT_SUM_MIN missing value counts: 50446, 0.14160% of column missing
# BURO_AMT_CREDIT_SUM_MAX missing value counts: 50446, 0.14160% of column missing
# BURO_AMT_CREDIT_SUM_MEAN missing value counts: 50446, 0.14160% of column missing
# BURO_AMT_CREDIT_SUM_DEBT_MIN missing value counts: 58816, 0.16510% of column missing
# BURO_AMT_CREDIT_SUM_DEBT_MAX missing value counts: 58816, 0.16510% of column missing
# BURO_AMT_CREDIT_SUM_DEBT_MEAN missing value counts: 58816, 0.16510% of column missing
# BURO_AMT_CREDIT_SUM_LIMIT_SUM missing value counts: 50444, 0.14160% of column missing
# BURO_AMT_CREDIT_SUM_LIMIT_MEAN missing value counts: 75752, 0.21264% of column missing
# BURO_AMT_CREDIT_SUM_OVERDUE_MEAN missing value counts: 50444, 0.14160% of column missing
# BURO_DAYS_CREDIT_UPDATE_MIN missing value counts: 50444, 0.14160% of column missing
# BURO_DAYS_CREDIT_UPDATE_MAX missing value counts: 50444, 0.14160% of column missing
# BURO_DAYS_CREDIT_UPDATE_MEAN missing value counts: 50444, 0.14160% of column missing
# BURO_AMT_ANNUITY_MAX missing value counts: 238027, 0.66814% of column missing
# BURO_AMT_ANNUITY_MEAN missing value counts: 238027, 0.66814% of column missing
# BURO_MONTHS_BALANCE_MIN_MIN missing value counts: 221709, 0.62234% of column missing
# BURO_MONTHS_BALANCE_MAX_MAX missing value counts: 221709, 0.62234% of column missing
# BURO_MONTHS_BALANCE_SIZE_MEAN missing value counts: 221709, 0.62234% of column missing
# BURO_MONTHS_BALANCE_SIZE_SUM missing value counts: 50444, 0.14160% of column missing
# BURO_CREDIT_ACTIVE_Active_MEAN missing value counts: 50444, 0.14160% of column missing
# BURO_CREDIT_ACTIVE_Closed_MEAN missing value counts: 50444, 0.14160% of column missing
# BURO_CREDIT_ACTIVE_Sold_MEAN missing value counts: 50444, 0.14160% of column missing
# BURO_CREDIT_TYPE_Car loan_MEAN missing value counts: 50444, 0.14160% of column missing
# BURO_CREDIT_TYPE_Consumer credit_MEAN missing value counts: 50444, 0.14160% of column missing
# BURO_CREDIT_TYPE_Credit card_MEAN missing value counts: 50444, 0.14160% of column missing
# BURO_CREDIT_TYPE_Microloan_MEAN missing value counts: 50444, 0.14160% of column missing
# BURO_CREDIT_TYPE_Mortgage_MEAN missing value counts: 50444, 0.14160% of column missing
# ACTIVE_DAYS_CREDIT_MIN missing value counts: 104440, 0.29316% of column missing
# ACTIVE_DAYS_CREDIT_MAX missing value counts: 104440, 0.29316% of column missing
# ACTIVE_DAYS_CREDIT_MEAN missing value counts: 104440, 0.29316% of column missing
# ACTIVE_DAYS_CREDIT_VAR missing value counts: 189928, 0.53313% of column missing
# ACTIVE_CREDIT_DAY_OVERDUE_MAX missing value counts: 104440, 0.29316% of column missing
# ACTIVE_CREDIT_DAY_OVERDUE_MEAN missing value counts: 104440, 0.29316% of column missing
# ACTIVE_DAYS_CREDIT_ENDDATE_MIN missing value counts: 114909, 0.32255% of column missing
# ACTIVE_DAYS_CREDIT_ENDDATE_MAX missing value counts: 114909, 0.32255% of column missing
# ACTIVE_DAYS_CREDIT_ENDDATE_MEAN missing value counts: 114909, 0.32255% of column missing
# ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN missing value counts: 223254, 0.62668% of column missing
# ACTIVE_CNT_CREDIT_PROLONG_COUNT missing value counts: 104440, 0.29316% of column missing
# ACTIVE_CNT_CREDIT_PROLONG_SUM missing value counts: 104440, 0.29316% of column missing
# ACTIVE_AMT_CREDIT_SUM_MIN missing value counts: 104443, 0.29317% of column missing
# ACTIVE_AMT_CREDIT_SUM_MAX missing value counts: 104443, 0.29317% of column missing
# ACTIVE_AMT_CREDIT_SUM_MEAN missing value counts: 104443, 0.29317% of column missing
# ACTIVE_AMT_CREDIT_SUM_DEBT_MIN missing value counts: 116391, 0.32671% of column missing
# ACTIVE_AMT_CREDIT_SUM_DEBT_MAX missing value counts: 116391, 0.32671% of column missing
# ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN missing value counts: 116391, 0.32671% of column missing
# ACTIVE_AMT_CREDIT_SUM_LIMIT_SUM missing value counts: 104440, 0.29316% of column missing
# ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN missing value counts: 138151, 0.38779% of column missing
# ACTIVE_AMT_CREDIT_SUM_OVERDUE_MEAN missing value counts: 104440, 0.29316% of column missing
# ACTIVE_DAYS_CREDIT_UPDATE_MIN missing value counts: 104440, 0.29316% of column missing
# ACTIVE_DAYS_CREDIT_UPDATE_MAX missing value counts: 104440, 0.29316% of column missing
# ACTIVE_DAYS_CREDIT_UPDATE_MEAN missing value counts: 104440, 0.29316% of column missing
# ACTIVE_AMT_ANNUITY_MAX missing value counts: 263525, 0.73972% of column missing
# ACTIVE_AMT_ANNUITY_MEAN missing value counts: 263525, 0.73972% of column missing
# ACTIVE_MONTHS_BALANCE_MIN_MIN missing value counts: 245102, 0.68800% of column missing
# ACTIVE_MONTHS_BALANCE_MAX_MAX missing value counts: 245102, 0.68800% of column missing
# ACTIVE_MONTHS_BALANCE_SIZE_MEAN missing value counts: 245102, 0.68800% of column missing
# ACTIVE_MONTHS_BALANCE_SIZE_SUM missing value counts: 104440, 0.29316% of column missing
# ACTIVE_CREDIT_TYPE_Car loan_MEAN missing value counts: 104440, 0.29316% of column missing
# ACTIVE_CREDIT_TYPE_Consumer credit_MEAN missing value counts: 104440, 0.29316% of column missing
# ACTIVE_CREDIT_TYPE_Credit card_MEAN missing value counts: 104440, 0.29316% of column missing
# ACTIVE_CREDIT_TYPE_Microloan_MEAN missing value counts: 104440, 0.29316% of column missing
# ACTIVE_CREDIT_TYPE_Mortgage_MEAN missing value counts: 104440, 0.29316% of column missing
# CLOSED_DAYS_CREDIT_MIN missing value counts: 88330, 0.24794% of column missing
# CLOSED_DAYS_CREDIT_MAX missing value counts: 88330, 0.24794% of column missing
# CLOSED_DAYS_CREDIT_MEAN missing value counts: 88330, 0.24794% of column missing
# CLOSED_DAYS_CREDIT_VAR missing value counts: 150025, 0.42112% of column missing
# CLOSED_DAYS_CREDIT_ENDDATE_MIN missing value counts: 90083, 0.25286% of column missing
# CLOSED_DAYS_CREDIT_ENDDATE_MAX missing value counts: 90083, 0.25286% of column missing
# CLOSED_DAYS_CREDIT_ENDDATE_MEAN missing value counts: 90083, 0.25286% of column missing
# CLOSED_DAYS_ENDDATE_FACT_MEAN missing value counts: 88355, 0.24801% of column missing
# CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN missing value counts: 186355, 0.52310% of column missing
# CLOSED_CNT_CREDIT_PROLONG_COUNT missing value counts: 88330, 0.24794% of column missing
# CLOSED_CNT_CREDIT_PROLONG_SUM missing value counts: 88330, 0.24794% of column missing
# CLOSED_AMT_CREDIT_SUM_MIN missing value counts: 88330, 0.24794% of column missing
# CLOSED_AMT_CREDIT_SUM_MAX missing value counts: 88330, 0.24794% of column missing
# CLOSED_AMT_CREDIT_SUM_MEAN missing value counts: 88330, 0.24794% of column missing
# CLOSED_AMT_CREDIT_SUM_DEBT_MIN missing value counts: 101919, 0.28609% of column missing
# CLOSED_AMT_CREDIT_SUM_DEBT_MAX missing value counts: 101919, 0.28609% of column missing
# CLOSED_AMT_CREDIT_SUM_DEBT_MEAN missing value counts: 101919, 0.28609% of column missing
# CLOSED_AMT_CREDIT_SUM_LIMIT_SUM missing value counts: 88330, 0.24794% of column missing
# CLOSED_AMT_CREDIT_SUM_LIMIT_MEAN missing value counts: 126314, 0.35456% of column missing
# CLOSED_DAYS_CREDIT_UPDATE_MIN missing value counts: 88330, 0.24794% of column missing
# CLOSED_DAYS_CREDIT_UPDATE_MAX missing value counts: 88330, 0.24794% of column missing
# CLOSED_DAYS_CREDIT_UPDATE_MEAN missing value counts: 88330, 0.24794% of column missing
# CLOSED_AMT_ANNUITY_MAX missing value counts: 261054, 0.73278% of column missing
# CLOSED_AMT_ANNUITY_MEAN missing value counts: 261054, 0.73278% of column missing
# CLOSED_MONTHS_BALANCE_MIN_MIN missing value counts: 237756, 0.66738% of column missing
# CLOSED_MONTHS_BALANCE_MAX_MAX missing value counts: 237756, 0.66738% of column missing
# CLOSED_MONTHS_BALANCE_SIZE_MEAN missing value counts: 237756, 0.66738% of column missing
# CLOSED_MONTHS_BALANCE_SIZE_SUM missing value counts: 88330, 0.24794% of column missing
# CLOSED_CREDIT_TYPE_Car loan_MEAN missing value counts: 88330, 0.24794% of column missing
# CLOSED_CREDIT_TYPE_Consumer credit_MEAN missing value counts: 88330, 0.24794% of column missing
# CLOSED_CREDIT_TYPE_Credit card_MEAN missing value counts: 88330, 0.24794% of column missing
# CLOSED_CREDIT_TYPE_Microloan_MEAN missing value counts: 88330, 0.24794% of column missing
# CLOSED_CREDIT_TYPE_Mortgage_MEAN missing value counts: 88330, 0.24794% of column missing
# NEW_RATIO_BURO_DAYS_CREDIT_MIN missing value counts: 142137, 0.39898% of column missing
# NEW_RATIO_BURO_DAYS_CREDIT_MAX missing value counts: 142137, 0.39898% of column missing
# NEW_RATIO_BURO_DAYS_CREDIT_MEAN missing value counts: 142137, 0.39898% of column missing
# NEW_RATIO_BURO_DAYS_CREDIT_VAR missing value counts: 229603, 0.64450% of column missing
# NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MIN missing value counts: 151736, 0.42592% of column missing
# NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MAX missing value counts: 151737, 0.42593% of column missing
# NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MEAN missing value counts: 151736, 0.42592% of column missing
# NEW_RATIO_BURO_AMT_CREDIT_MAX_OVERDUE_MEAN missing value counts: 310048, 0.87031% of column missing
# NEW_RATIO_BURO_CNT_CREDIT_PROLONG_COUNT missing value counts: 142137, 0.39898% of column missing
# NEW_RATIO_BURO_CNT_CREDIT_PROLONG_SUM missing value counts: 348556, 0.97840% of column missing
# NEW_RATIO_BURO_AMT_CREDIT_SUM_MIN missing value counts: 146035, 0.40992% of column missing
# NEW_RATIO_BURO_AMT_CREDIT_SUM_MAX missing value counts: 142180, 0.39910% of column missing
# NEW_RATIO_BURO_AMT_CREDIT_SUM_MEAN missing value counts: 142180, 0.39910% of column missing
# NEW_RATIO_BURO_AMT_CREDIT_SUM_DEBT_MIN missing value counts: 235178, 0.66015% of column missing
# NEW_RATIO_BURO_AMT_CREDIT_SUM_DEBT_MAX missing value counts: 179171, 0.50293% of column missing
# NEW_RATIO_BURO_AMT_CREDIT_SUM_DEBT_MEAN missing value counts: 178578, 0.50127% of column missing
# NEW_RATIO_BURO_AMT_CREDIT_SUM_LIMIT_SUM missing value counts: 305169, 0.85661% of column missing
# NEW_RATIO_BURO_AMT_CREDIT_SUM_LIMIT_MEAN missing value counts: 309428, 0.86857% of column missing
# NEW_RATIO_BURO_DAYS_CREDIT_UPDATE_MIN missing value counts: 142139, 0.39899% of column missing
# NEW_RATIO_BURO_DAYS_CREDIT_UPDATE_MAX missing value counts: 142169, 0.39907% of column missing
# NEW_RATIO_BURO_DAYS_CREDIT_UPDATE_MEAN missing value counts: 142139, 0.39899% of column missing
# NEW_RATIO_BURO_AMT_ANNUITY_MAX missing value counts: 295549, 0.82961% of column missing
# NEW_RATIO_BURO_AMT_ANNUITY_MEAN missing value counts: 295549, 0.82961% of column missing
# NEW_RATIO_BURO_MONTHS_BALANCE_MIN_MIN missing value counts: 261083, 0.73286% of column missing
# NEW_RATIO_BURO_MONTHS_BALANCE_MAX_MAX missing value counts: 342441, 0.96124% of column missing
# NEW_RATIO_BURO_MONTHS_BALANCE_SIZE_MEAN missing value counts: 261078, 0.73285% of column missing
# NEW_RATIO_BURO_MONTHS_BALANCE_SIZE_SUM missing value counts: 261031, 0.73272% of column missing
# NEW_RATIO_BURO_CREDIT_CURRENCY_currency 1_MEAN missing value counts: 142138, 0.39898% of column missing
# NEW_RATIO_BURO_CREDIT_TYPE_Car loan_MEAN missing value counts: 337406, 0.94710% of column missing
# NEW_RATIO_BURO_CREDIT_TYPE_Consumer credit_MEAN missing value counts: 144914, 0.40677% of column missing
# NEW_RATIO_BURO_CREDIT_TYPE_Credit card_MEAN missing value counts: 189238, 0.53119% of column missing
# NEW_RATIO_BURO_CREDIT_TYPE_Microloan_MEAN missing value counts: 352199, 0.98863% of column missing
# NEW_RATIO_BURO_CREDIT_TYPE_Mortgage_MEAN missing value counts: 342364, 0.96102% of column missing
# CC_MONTHS_BALANCE_MIN missing value counts: 252693, 0.70931% of column missing
# CC_MONTHS_BALANCE_MAX missing value counts: 252693, 0.70931% of column missing
# CC_MONTHS_BALANCE_MEAN missing value counts: 252693, 0.70931% of column missing
# CC_MONTHS_BALANCE_SUM missing value counts: 252693, 0.70931% of column missing
# CC_MONTHS_BALANCE_VAR missing value counts: 253385, 0.71125% of column missing
# CC_AMT_BALANCE_MIN missing value counts: 252693, 0.70931% of column missing
# CC_AMT_BALANCE_MAX missing value counts: 252693, 0.70931% of column missing
# CC_AMT_BALANCE_MEAN missing value counts: 252693, 0.70931% of column missing
# CC_AMT_BALANCE_SUM missing value counts: 252693, 0.70931% of column missing
# CC_AMT_BALANCE_VAR missing value counts: 253385, 0.71125% of column missing
# CC_AMT_CREDIT_LIMIT_ACTUAL_MIN missing value counts: 252693, 0.70931% of column missing
# CC_AMT_CREDIT_LIMIT_ACTUAL_MAX missing value counts: 252693, 0.70931% of column missing
# CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN missing value counts: 252693, 0.70931% of column missing
# CC_AMT_CREDIT_LIMIT_ACTUAL_SUM missing value counts: 252693, 0.70931% of column missing
# CC_AMT_CREDIT_LIMIT_ACTUAL_VAR missing value counts: 253385, 0.71125% of column missing
# CC_AMT_DRAWINGS_ATM_CURRENT_MAX missing value counts: 284057, 0.79735% of column missing
# CC_AMT_DRAWINGS_ATM_CURRENT_MEAN missing value counts: 284057, 0.79735% of column missing
# CC_AMT_DRAWINGS_ATM_CURRENT_SUM missing value counts: 252693, 0.70931% of column missing
# CC_AMT_DRAWINGS_ATM_CURRENT_VAR missing value counts: 284559, 0.79876% of column missing
# CC_AMT_DRAWINGS_CURRENT_MIN missing value counts: 252693, 0.70931% of column missing
# CC_AMT_DRAWINGS_CURRENT_MAX missing value counts: 252693, 0.70931% of column missing
# CC_AMT_DRAWINGS_CURRENT_MEAN missing value counts: 252693, 0.70931% of column missing
# CC_AMT_DRAWINGS_CURRENT_SUM missing value counts: 252693, 0.70931% of column missing
# CC_AMT_DRAWINGS_CURRENT_VAR missing value counts: 253385, 0.71125% of column missing
# CC_AMT_DRAWINGS_OTHER_CURRENT_MAX missing value counts: 284057, 0.79735% of column missing
# CC_AMT_DRAWINGS_OTHER_CURRENT_MEAN missing value counts: 284057, 0.79735% of column missing
# CC_AMT_DRAWINGS_OTHER_CURRENT_SUM missing value counts: 252693, 0.70931% of column missing
# CC_AMT_DRAWINGS_OTHER_CURRENT_VAR missing value counts: 284559, 0.79876% of column missing
# CC_AMT_DRAWINGS_POS_CURRENT_MIN missing value counts: 284057, 0.79735% of column missing
# CC_AMT_DRAWINGS_POS_CURRENT_MAX missing value counts: 284057, 0.79735% of column missing
# CC_AMT_DRAWINGS_POS_CURRENT_MEAN missing value counts: 284057, 0.79735% of column missing
# CC_AMT_DRAWINGS_POS_CURRENT_SUM missing value counts: 252693, 0.70931% of column missing
# CC_AMT_DRAWINGS_POS_CURRENT_VAR missing value counts: 284559, 0.79876% of column missing
# CC_AMT_INST_MIN_REGULARITY_MIN missing value counts: 252693, 0.70931% of column missing
# CC_AMT_INST_MIN_REGULARITY_MAX missing value counts: 252693, 0.70931% of column missing
# CC_AMT_INST_MIN_REGULARITY_MEAN missing value counts: 252693, 0.70931% of column missing
# CC_AMT_INST_MIN_REGULARITY_SUM missing value counts: 252693, 0.70931% of column missing
# CC_AMT_INST_MIN_REGULARITY_VAR missing value counts: 253385, 0.71125% of column missing
# CC_AMT_PAYMENT_CURRENT_MIN missing value counts: 284131, 0.79756% of column missing
# CC_AMT_PAYMENT_CURRENT_MAX missing value counts: 284131, 0.79756% of column missing
# CC_AMT_PAYMENT_CURRENT_MEAN missing value counts: 284131, 0.79756% of column missing
# CC_AMT_PAYMENT_CURRENT_SUM missing value counts: 252693, 0.70931% of column missing
# CC_AMT_PAYMENT_CURRENT_VAR missing value counts: 284649, 0.79901% of column missing
# CC_AMT_PAYMENT_TOTAL_CURRENT_MIN missing value counts: 252693, 0.70931% of column missing
# CC_AMT_PAYMENT_TOTAL_CURRENT_MAX missing value counts: 252693, 0.70931% of column missing
# CC_AMT_PAYMENT_TOTAL_CURRENT_MEAN missing value counts: 252693, 0.70931% of column missing
# CC_AMT_PAYMENT_TOTAL_CURRENT_SUM missing value counts: 252693, 0.70931% of column missing
# CC_AMT_PAYMENT_TOTAL_CURRENT_VAR missing value counts: 253385, 0.71125% of column missing
# CC_AMT_RECEIVABLE_PRINCIPAL_MIN missing value counts: 252693, 0.70931% of column missing
# CC_AMT_RECEIVABLE_PRINCIPAL_MAX missing value counts: 252693, 0.70931% of column missing
# CC_AMT_RECEIVABLE_PRINCIPAL_MEAN missing value counts: 252693, 0.70931% of column missing
# CC_AMT_RECEIVABLE_PRINCIPAL_SUM missing value counts: 252693, 0.70931% of column missing
# CC_AMT_RECEIVABLE_PRINCIPAL_VAR missing value counts: 253385, 0.71125% of column missing
# CC_AMT_RECIVABLE_MIN missing value counts: 252693, 0.70931% of column missing
# CC_AMT_RECIVABLE_MAX missing value counts: 252693, 0.70931% of column missing
# CC_AMT_RECIVABLE_MEAN missing value counts: 252693, 0.70931% of column missing
# CC_AMT_RECIVABLE_SUM missing value counts: 252693, 0.70931% of column missing
# CC_AMT_RECIVABLE_VAR missing value counts: 253385, 0.71125% of column missing
# CC_AMT_TOTAL_RECEIVABLE_MIN missing value counts: 252693, 0.70931% of column missing
# CC_AMT_TOTAL_RECEIVABLE_MAX missing value counts: 252693, 0.70931% of column missing
# CC_AMT_TOTAL_RECEIVABLE_MEAN missing value counts: 252693, 0.70931% of column missing
# CC_AMT_TOTAL_RECEIVABLE_SUM missing value counts: 252693, 0.70931% of column missing
# CC_AMT_TOTAL_RECEIVABLE_VAR missing value counts: 253385, 0.71125% of column missing
# CC_CNT_DRAWINGS_ATM_CURRENT_MAX missing value counts: 284057, 0.79735% of column missing
# CC_CNT_DRAWINGS_ATM_CURRENT_MEAN missing value counts: 284057, 0.79735% of column missing
# CC_CNT_DRAWINGS_ATM_CURRENT_SUM missing value counts: 252693, 0.70931% of column missing
# CC_CNT_DRAWINGS_ATM_CURRENT_VAR missing value counts: 284559, 0.79876% of column missing
# CC_CNT_DRAWINGS_CURRENT_MAX missing value counts: 252693, 0.70931% of column missing
# CC_CNT_DRAWINGS_CURRENT_MEAN missing value counts: 252693, 0.70931% of column missing
# CC_CNT_DRAWINGS_CURRENT_SUM missing value counts: 252693, 0.70931% of column missing
# CC_CNT_DRAWINGS_CURRENT_VAR missing value counts: 253385, 0.71125% of column missing
# CC_CNT_DRAWINGS_OTHER_CURRENT_MEAN missing value counts: 284057, 0.79735% of column missing
# CC_CNT_DRAWINGS_OTHER_CURRENT_VAR missing value counts: 284559, 0.79876% of column missing
# CC_CNT_DRAWINGS_POS_CURRENT_MIN missing value counts: 284057, 0.79735% of column missing
# CC_CNT_DRAWINGS_POS_CURRENT_MAX missing value counts: 284057, 0.79735% of column missing
# CC_CNT_DRAWINGS_POS_CURRENT_MEAN missing value counts: 284057, 0.79735% of column missing
# CC_CNT_DRAWINGS_POS_CURRENT_SUM missing value counts: 252693, 0.70931% of column missing
# CC_CNT_DRAWINGS_POS_CURRENT_VAR missing value counts: 284559, 0.79876% of column missing
# CC_CNT_INSTALMENT_MATURE_CUM_MIN missing value counts: 252693, 0.70931% of column missing
# CC_CNT_INSTALMENT_MATURE_CUM_MAX missing value counts: 252693, 0.70931% of column missing
# CC_CNT_INSTALMENT_MATURE_CUM_MEAN missing value counts: 252693, 0.70931% of column missing
# CC_CNT_INSTALMENT_MATURE_CUM_SUM missing value counts: 252693, 0.70931% of column missing
# CC_CNT_INSTALMENT_MATURE_CUM_VAR missing value counts: 253385, 0.71125% of column missing
# CC_SK_DPD_MAX missing value counts: 252693, 0.70931% of column missing
# CC_SK_DPD_MEAN missing value counts: 252693, 0.70931% of column missing
# CC_SK_DPD_SUM missing value counts: 252693, 0.70931% of column missing
# CC_SK_DPD_VAR missing value counts: 253385, 0.71125% of column missing
# CC_SK_DPD_DEF_MEAN missing value counts: 252693, 0.70931% of column missing
# CC_SK_DPD_DEF_SUM missing value counts: 252693, 0.70931% of column missing
# CC_SK_DPD_DEF_VAR missing value counts: 253385, 0.71125% of column missing
# INSTAL_NUM_INSTALMENT_VERSION_NUNIQUE missing value counts: 16668, 0.04679% of column missing
# INSTAL_DPD_MAX missing value counts: 16668, 0.04679% of column missing
# INSTAL_DPD_MEAN missing value counts: 16668, 0.04679% of column missing
# INSTAL_DPD_SUM missing value counts: 16668, 0.04679% of column missing
# INSTAL_DBD_MAX missing value counts: 16668, 0.04679% of column missing
# INSTAL_DBD_MEAN missing value counts: 16668, 0.04679% of column missing
# INSTAL_DBD_SUM missing value counts: 16668, 0.04679% of column missing
# INSTAL_PAYMENT_PERC_MAX missing value counts: 16677, 0.04681% of column missing
# INSTAL_PAYMENT_PERC_MEAN missing value counts: 16677, 0.04681% of column missing
# INSTAL_PAYMENT_PERC_SUM missing value counts: 16668, 0.04679% of column missing
# INSTAL_PAYMENT_PERC_VAR missing value counts: 17664, 0.04958% of column missing
# INSTAL_AMT_INSTALMENT_MAX missing value counts: 16668, 0.04679% of column missing
# INSTAL_AMT_INSTALMENT_MEAN missing value counts: 16668, 0.04679% of column missing
# INSTAL_AMT_INSTALMENT_SUM missing value counts: 16668, 0.04679% of column missing
# INSTAL_AMT_PAYMENT_MIN missing value counts: 16677, 0.04681% of column missing
# INSTAL_AMT_PAYMENT_MAX missing value counts: 16677, 0.04681% of column missing
# INSTAL_AMT_PAYMENT_MEAN missing value counts: 16677, 0.04681% of column missing
# INSTAL_AMT_PAYMENT_SUM missing value counts: 16668, 0.04679% of column missing
# INSTAL_DAYS_ENTRY_PAYMENT_MAX missing value counts: 16677, 0.04681% of column missing
# INSTAL_DAYS_ENTRY_PAYMENT_MEAN missing value counts: 16677, 0.04681% of column missing
# INSTAL_DAYS_ENTRY_PAYMENT_SUM missing value counts: 16668, 0.04679% of column missing
# INSTAL_INSTALLMENTS_DAY_DIFF_MAX missing value counts: 16677, 0.04681% of column missing
# INSTAL_INSTALLMENTS_DAY_DIFF_MEAN missing value counts: 16677, 0.04681% of column missing
# INSTAL_INSTALLMENTS_DAY_DIFF_SUM missing value counts: 16668, 0.04679% of column missing
# INSTAL_INSTALLMENTS_DAY_DIFF_VAR missing value counts: 17645, 0.04953% of column missing
# INSTAL_INSTALLMENTS_DIFF_MAX missing value counts: 16677, 0.04681% of column missing
# INSTAL_INSTALLMENTS_DIFF_MEAN missing value counts: 16677, 0.04681% of column missing
# INSTAL_INSTALLMENTS_DIFF_SUM missing value counts: 16668, 0.04679% of column missing
# INSTAL_INSTALLMENTS_DIFF_VAR missing value counts: 17645, 0.04953% of column missing
# INSTAL_INSTALLMENTS_DIFF_INSTALLMENTS_DAY_DIFF_MAX missing value counts: 16677, 0.04681% of column missing
# INSTAL_INSTALLMENTS_DIFF_INSTALLMENTS_DAY_DIFF_MEAN missing value counts: 16677, 0.04681% of column missing
# INSTAL_INSTALLMENTS_DIFF_INSTALLMENTS_DAY_DIFF_SUM missing value counts: 16668, 0.04679% of column missing
# INSTAL_INSTALLMENTS_DIFF_INSTALLMENTS_DAY_DIFF_VAR missing value counts: 17645, 0.04953% of column missing
# INSTAL_INSTALLMENTS_DIFF_INSTALLMENTS_DIFF_MAX missing value counts: 16677, 0.04681% of column missing
# INSTAL_INSTALLMENTS_DIFF_INSTALLMENTS_DIFF_MEAN missing value counts: 16677, 0.04681% of column missing
# INSTAL_INSTALLMENTS_DIFF_INSTALLMENTS_DIFF_SUM missing value counts: 16668, 0.04679% of column missing
# INSTAL_INSTALLMENTS_DIFF_INSTALLMENTS_DIFF_VAR missing value counts: 17645, 0.04953% of column missing
# INSTAL_INSTALLMENTS_DAY_DIFF_INSTALLMENTS_DAY_DIFF_MAX missing value counts: 16677, 0.04681% of column missing
# INSTAL_INSTALLMENTS_DAY_DIFF_INSTALLMENTS_DAY_DIFF_MEAN missing value counts: 16677, 0.04681% of column missing
# INSTAL_INSTALLMENTS_DAY_DIFF_INSTALLMENTS_DAY_DIFF_SUM missing value counts: 16668, 0.04679% of column missing
# INSTAL_INSTALLMENTS_DAY_DIFF_INSTALLMENTS_DAY_DIFF_VAR missing value counts: 17645, 0.04953% of column missing
# INSTAL_COUNT missing value counts: 16668, 0.04679% of column missing
# POS_MONTHS_BALANCE_MAX missing value counts: 19003, 0.05334% of column missing
# POS_MONTHS_BALANCE_MEAN missing value counts: 19003, 0.05334% of column missing
# POS_MONTHS_BALANCE_SIZE missing value counts: 19003, 0.05334% of column missing
# POS_SK_DPD_MAX missing value counts: 19003, 0.05334% of column missing
# POS_SK_DPD_MEAN missing value counts: 19003, 0.05334% of column missing
# POS_SK_DPD_DEF_MAX missing value counts: 19003, 0.05334% of column missing
# POS_SK_DPD_DEF_MEAN missing value counts: 19003, 0.05334% of column missing
# POS_CNT_INSTALMENT_MIN missing value counts: 19031, 0.05342% of column missing
# POS_CNT_INSTALMENT_MAX missing value counts: 19031, 0.05342% of column missing
# POS_CNT_INSTALMENT_MEAN missing value counts: 19031, 0.05342% of column missing
# POS_CNT_INSTALMENT_FUTURE_MIN missing value counts: 19031, 0.05342% of column missing
# POS_CNT_INSTALMENT_FUTURE_MAX missing value counts: 19031, 0.05342% of column missing
# POS_CNT_INSTALMENT_FUTURE_MEAN missing value counts: 19031, 0.05342% of column missing
# POS_COUNT missing value counts: 19003, 0.05334% of column missing
# PREV_AMT_ANNUITY_MIN missing value counts: 17878, 0.05018% of column missing
# PREV_AMT_ANNUITY_MAX missing value counts: 17878, 0.05018% of column missing
# PREV_AMT_ANNUITY_MEAN missing value counts: 17878, 0.05018% of column missing
# PREV_AMT_APPLICATION_MIN missing value counts: 17398, 0.04884% of column missing
# PREV_AMT_APPLICATION_MAX missing value counts: 17398, 0.04884% of column missing
# PREV_AMT_APPLICATION_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_AMT_CREDIT_MIN missing value counts: 17398, 0.04884% of column missing
# PREV_AMT_CREDIT_MAX missing value counts: 17398, 0.04884% of column missing
# PREV_AMT_CREDIT_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_APP_CREDIT_PERC_MIN missing value counts: 17650, 0.04954% of column missing
# PREV_APP_CREDIT_PERC_MAX missing value counts: 17650, 0.04954% of column missing
# PREV_APP_CREDIT_PERC_MEAN missing value counts: 17650, 0.04954% of column missing
# PREV_APP_CREDIT_PERC_VAR missing value counts: 88434, 0.24824% of column missing
# PREV_AMT_DOWN_PAYMENT_MIN missing value counts: 37502, 0.10527% of column missing
# PREV_AMT_DOWN_PAYMENT_MAX missing value counts: 37502, 0.10527% of column missing
# PREV_AMT_DOWN_PAYMENT_MEAN missing value counts: 37502, 0.10527% of column missing
# PREV_AMT_GOODS_PRICE_MIN missing value counts: 18462, 0.05182% of column missing
# PREV_AMT_GOODS_PRICE_MAX missing value counts: 18462, 0.05182% of column missing
# PREV_AMT_GOODS_PRICE_MEAN missing value counts: 18462, 0.05182% of column missing
# PREV_HOUR_APPR_PROCESS_START_MIN missing value counts: 17398, 0.04884% of column missing
# PREV_HOUR_APPR_PROCESS_START_MAX missing value counts: 17398, 0.04884% of column missing
# PREV_HOUR_APPR_PROCESS_START_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_RATE_DOWN_PAYMENT_MIN missing value counts: 37502, 0.10527% of column missing
# PREV_RATE_DOWN_PAYMENT_MAX missing value counts: 37502, 0.10527% of column missing
# PREV_RATE_DOWN_PAYMENT_MEAN missing value counts: 37502, 0.10527% of column missing
# PREV_DAYS_DECISION_MIN missing value counts: 17398, 0.04884% of column missing
# PREV_DAYS_DECISION_MAX missing value counts: 17398, 0.04884% of column missing
# PREV_DAYS_DECISION_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_CNT_PAYMENT_MEAN missing value counts: 17876, 0.05018% of column missing
# PREV_CNT_PAYMENT_SUM missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_CONTRACT_TYPE_Cash loans_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_CONTRACT_TYPE_Revolving loans_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_WEEKDAY_APPR_PROCESS_START_FRIDAY_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_WEEKDAY_APPR_PROCESS_START_MONDAY_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_WEEKDAY_APPR_PROCESS_START_SATURDAY_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_WEEKDAY_APPR_PROCESS_START_SUNDAY_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_WEEKDAY_APPR_PROCESS_START_TUESDAY_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_FLAG_LAST_APPL_PER_CONTRACT_N_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_FLAG_LAST_APPL_PER_CONTRACT_Y_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_CASH_LOAN_PURPOSE_Building a house or an annex_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_CASH_LOAN_PURPOSE_Buying a used car_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_CASH_LOAN_PURPOSE_Car repairs_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_CASH_LOAN_PURPOSE_Education_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_CASH_LOAN_PURPOSE_Everyday expenses_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_CASH_LOAN_PURPOSE_Medicine_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_CASH_LOAN_PURPOSE_Other_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_CASH_LOAN_PURPOSE_Payments on other loans_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_CASH_LOAN_PURPOSE_Repairs_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_CASH_LOAN_PURPOSE_Urgent needs_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_CASH_LOAN_PURPOSE_XAP_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_CASH_LOAN_PURPOSE_XNA_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_CONTRACT_STATUS_Approved_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_CONTRACT_STATUS_Canceled_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_CONTRACT_STATUS_Refused_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_CONTRACT_STATUS_Unused offer_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_PAYMENT_TYPE_Cash through the bank_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_PAYMENT_TYPE_Non-cash from your account_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_PAYMENT_TYPE_XNA_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_CODE_REJECT_REASON_CLIENT_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_CODE_REJECT_REASON_HC_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_CODE_REJECT_REASON_LIMIT_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_CODE_REJECT_REASON_SCO_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_CODE_REJECT_REASON_SCOFR_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_CODE_REJECT_REASON_VERIF_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_CODE_REJECT_REASON_XAP_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_CODE_REJECT_REASON_XNA_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_TYPE_SUITE_Children_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_TYPE_SUITE_Family_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_TYPE_SUITE_Group of people_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_TYPE_SUITE_Other_A_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_TYPE_SUITE_Other_B_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_TYPE_SUITE_Spouse, partner_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_TYPE_SUITE_nan_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_CLIENT_TYPE_New_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_CLIENT_TYPE_Refreshed_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_CLIENT_TYPE_Repeater_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_GOODS_CATEGORY_Audio/Video_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_GOODS_CATEGORY_Auto Accessories_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_GOODS_CATEGORY_Clothing and Accessories_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_GOODS_CATEGORY_Computers_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_GOODS_CATEGORY_Construction Materials_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_GOODS_CATEGORY_Consumer Electronics_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_GOODS_CATEGORY_Furniture_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_GOODS_CATEGORY_Gardening_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_GOODS_CATEGORY_Jewelry_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_GOODS_CATEGORY_Medical Supplies_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_GOODS_CATEGORY_Mobile_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_GOODS_CATEGORY_Other_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_GOODS_CATEGORY_Photo / Cinema Equipment_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_GOODS_CATEGORY_Sport and Leisure_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_GOODS_CATEGORY_Vehicles_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_GOODS_CATEGORY_XNA_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_PORTFOLIO_Cards_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_PORTFOLIO_Cash_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_PORTFOLIO_POS_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_PORTFOLIO_XNA_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_PRODUCT_TYPE_XNA_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_PRODUCT_TYPE_walk-in_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_PRODUCT_TYPE_x-sell_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_CHANNEL_TYPE_AP+ (Cash loan)_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_CHANNEL_TYPE_Channel of corporate sales_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_CHANNEL_TYPE_Contact center_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_CHANNEL_TYPE_Country-wide_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_CHANNEL_TYPE_Credit and cash offices_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_CHANNEL_TYPE_Regional / Local_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_CHANNEL_TYPE_Stone_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_SELLER_INDUSTRY_Auto technology_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_SELLER_INDUSTRY_Clothing_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_SELLER_INDUSTRY_Construction_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_SELLER_INDUSTRY_Consumer electronics_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_SELLER_INDUSTRY_Furniture_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_SELLER_INDUSTRY_Industry_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_SELLER_INDUSTRY_Jewelry_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_SELLER_INDUSTRY_XNA_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_YIELD_GROUP_XNA_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_YIELD_GROUP_high_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_YIELD_GROUP_low_action_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_YIELD_GROUP_low_normal_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_NAME_YIELD_GROUP_middle_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_PRODUCT_COMBINATION_Card Street_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_PRODUCT_COMBINATION_Card X-Sell_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_PRODUCT_COMBINATION_Cash_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_PRODUCT_COMBINATION_Cash Street: high_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_PRODUCT_COMBINATION_Cash Street: low_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_PRODUCT_COMBINATION_Cash Street: middle_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_PRODUCT_COMBINATION_Cash X-Sell: high_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_PRODUCT_COMBINATION_Cash X-Sell: low_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_PRODUCT_COMBINATION_Cash X-Sell: middle_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_PRODUCT_COMBINATION_POS household with interest_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_PRODUCT_COMBINATION_POS household without interest_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_PRODUCT_COMBINATION_POS industry with interest_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_PRODUCT_COMBINATION_POS industry without interest_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_PRODUCT_COMBINATION_POS mobile with interest_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_PRODUCT_COMBINATION_POS mobile without interest_MEAN missing value counts: 17398, 0.04884% of column missing
# PREV_PRODUCT_COMBINATION_POS other with interest_MEAN missing value counts: 17398, 0.04884% of column missing
# APPROVED_AMT_ANNUITY_MIN missing value counts: 18559, 0.05210% of column missing
# APPROVED_AMT_ANNUITY_MAX missing value counts: 18559, 0.05210% of column missing
# APPROVED_AMT_ANNUITY_MEAN missing value counts: 18559, 0.05210% of column missing
# APPROVED_AMT_APPLICATION_MIN missing value counts: 18557, 0.05209% of column missing
# APPROVED_AMT_APPLICATION_MAX missing value counts: 18557, 0.05209% of column missing
# APPROVED_AMT_APPLICATION_MEAN missing value counts: 18557, 0.05209% of column missing
# APPROVED_AMT_CREDIT_MIN missing value counts: 18557, 0.05209% of column missing
# APPROVED_AMT_CREDIT_MAX missing value counts: 18557, 0.05209% of column missing
# APPROVED_AMT_CREDIT_MEAN missing value counts: 18557, 0.05209% of column missing
# APPROVED_APP_CREDIT_PERC_MIN missing value counts: 18566, 0.05211% of column missing
# APPROVED_APP_CREDIT_PERC_MAX missing value counts: 18566, 0.05211% of column missing
# APPROVED_APP_CREDIT_PERC_MEAN missing value counts: 18566, 0.05211% of column missing
# APPROVED_APP_CREDIT_PERC_VAR missing value counts: 107148, 0.30077% of column missing
# APPROVED_AMT_DOWN_PAYMENT_MIN missing value counts: 40203, 0.11285% of column missing
# APPROVED_AMT_DOWN_PAYMENT_MAX missing value counts: 40203, 0.11285% of column missing
# APPROVED_AMT_DOWN_PAYMENT_MEAN missing value counts: 40203, 0.11285% of column missing
# APPROVED_AMT_GOODS_PRICE_MIN missing value counts: 19634, 0.05511% of column missing
# APPROVED_AMT_GOODS_PRICE_MAX missing value counts: 19634, 0.05511% of column missing
# APPROVED_AMT_GOODS_PRICE_MEAN missing value counts: 19634, 0.05511% of column missing
# APPROVED_HOUR_APPR_PROCESS_START_MIN missing value counts: 18557, 0.05209% of column missing
# APPROVED_HOUR_APPR_PROCESS_START_MAX missing value counts: 18557, 0.05209% of column missing
# APPROVED_HOUR_APPR_PROCESS_START_MEAN missing value counts: 18557, 0.05209% of column missing
# APPROVED_RATE_DOWN_PAYMENT_MIN missing value counts: 40203, 0.11285% of column missing
# APPROVED_RATE_DOWN_PAYMENT_MAX missing value counts: 40203, 0.11285% of column missing
# APPROVED_RATE_DOWN_PAYMENT_MEAN missing value counts: 40203, 0.11285% of column missing
# APPROVED_DAYS_DECISION_MIN missing value counts: 18557, 0.05209% of column missing
# APPROVED_DAYS_DECISION_MAX missing value counts: 18557, 0.05209% of column missing
# APPROVED_DAYS_DECISION_MEAN missing value counts: 18557, 0.05209% of column missing
# APPROVED_CNT_PAYMENT_MEAN missing value counts: 18557, 0.05209% of column missing
# APPROVED_CNT_PAYMENT_SUM missing value counts: 18557, 0.05209% of column missing
# REFUSED_AMT_ANNUITY_MIN missing value counts: 248159, 0.69658% of column missing
# REFUSED_AMT_ANNUITY_MAX missing value counts: 248159, 0.69658% of column missing
# REFUSED_AMT_ANNUITY_MEAN missing value counts: 248159, 0.69658% of column missing
# REFUSED_AMT_APPLICATION_MIN missing value counts: 237978, 0.66801% of column missing
# REFUSED_AMT_APPLICATION_MAX missing value counts: 237978, 0.66801% of column missing
# REFUSED_AMT_APPLICATION_MEAN missing value counts: 237978, 0.66801% of column missing
# REFUSED_AMT_CREDIT_MIN missing value counts: 237978, 0.66801% of column missing
# REFUSED_AMT_CREDIT_MAX missing value counts: 237978, 0.66801% of column missing
# REFUSED_AMT_CREDIT_MEAN missing value counts: 237978, 0.66801% of column missing
# REFUSED_APP_CREDIT_PERC_MIN missing value counts: 243798, 0.68434% of column missing
# REFUSED_APP_CREDIT_PERC_MAX missing value counts: 243798, 0.68434% of column missing
# REFUSED_APP_CREDIT_PERC_MEAN missing value counts: 243798, 0.68434% of column missing
# REFUSED_APP_CREDIT_PERC_VAR missing value counts: 298034, 0.83658% of column missing
# REFUSED_AMT_DOWN_PAYMENT_MIN missing value counts: 303648, 0.85234% of column missing
# REFUSED_AMT_DOWN_PAYMENT_MAX missing value counts: 303648, 0.85234% of column missing
# REFUSED_AMT_DOWN_PAYMENT_MEAN missing value counts: 303648, 0.85234% of column missing
# REFUSED_AMT_GOODS_PRICE_MIN missing value counts: 246213, 0.69112% of column missing
# REFUSED_AMT_GOODS_PRICE_MAX missing value counts: 246213, 0.69112% of column missing
# REFUSED_AMT_GOODS_PRICE_MEAN missing value counts: 246213, 0.69112% of column missing
# REFUSED_HOUR_APPR_PROCESS_START_MIN missing value counts: 237978, 0.66801% of column missing
# REFUSED_HOUR_APPR_PROCESS_START_MAX missing value counts: 237978, 0.66801% of column missing
# REFUSED_HOUR_APPR_PROCESS_START_MEAN missing value counts: 237978, 0.66801% of column missing
# REFUSED_RATE_DOWN_PAYMENT_MIN missing value counts: 303648, 0.85234% of column missing
# REFUSED_RATE_DOWN_PAYMENT_MAX missing value counts: 303648, 0.85234% of column missing
# REFUSED_RATE_DOWN_PAYMENT_MEAN missing value counts: 303648, 0.85234% of column missing
# REFUSED_DAYS_DECISION_MIN missing value counts: 237978, 0.66801% of column missing
# REFUSED_DAYS_DECISION_MAX missing value counts: 237978, 0.66801% of column missing
# REFUSED_DAYS_DECISION_MEAN missing value counts: 237978, 0.66801% of column missing
# REFUSED_CNT_PAYMENT_MEAN missing value counts: 248159, 0.69658% of column missing
# REFUSED_CNT_PAYMENT_SUM missing value counts: 237978, 0.66801% of column missing
# NEW_RATIO_PREV_AMT_ANNUITY_MIN missing value counts: 248809, 0.69841% of column missing
# NEW_RATIO_PREV_AMT_ANNUITY_MAX missing value counts: 248808, 0.69841% of column missing
# NEW_RATIO_PREV_AMT_ANNUITY_MEAN missing value counts: 248808, 0.69841% of column missing
# NEW_RATIO_PREV_AMT_APPLICATION_MIN missing value counts: 243926, 0.68470% of column missing
# NEW_RATIO_PREV_AMT_APPLICATION_MAX missing value counts: 238742, 0.67015% of column missing
# NEW_RATIO_PREV_AMT_APPLICATION_MEAN missing value counts: 238742, 0.67015% of column missing
# NEW_RATIO_PREV_AMT_CREDIT_MIN missing value counts: 238762, 0.67021% of column missing
# NEW_RATIO_PREV_AMT_CREDIT_MAX missing value counts: 238682, 0.66998% of column missing
# NEW_RATIO_PREV_AMT_CREDIT_MEAN missing value counts: 238682, 0.66998% of column missing
# NEW_RATIO_PREV_APP_CREDIT_PERC_MIN missing value counts: 247443, 0.69457% of column missing
# NEW_RATIO_PREV_APP_CREDIT_PERC_MAX missing value counts: 244535, 0.68641% of column missing
# NEW_RATIO_PREV_APP_CREDIT_PERC_MEAN missing value counts: 244535, 0.68641% of column missing
# NEW_RATIO_PREV_APP_CREDIT_PERC_VAR missing value counts: 304907, 0.85588% of column missing
# NEW_RATIO_PREV_AMT_DOWN_PAYMENT_MIN missing value counts: 329592, 0.92517% of column missing
# NEW_RATIO_PREV_AMT_DOWN_PAYMENT_MAX missing value counts: 313295, 0.87942% of column missing
# NEW_RATIO_PREV_AMT_DOWN_PAYMENT_MEAN missing value counts: 313295, 0.87942% of column missing
# NEW_RATIO_PREV_AMT_GOODS_PRICE_MIN missing value counts: 247259, 0.69406% of column missing
# NEW_RATIO_PREV_AMT_GOODS_PRICE_MAX missing value counts: 247106, 0.69363% of column missing
# NEW_RATIO_PREV_AMT_GOODS_PRICE_MEAN missing value counts: 247106, 0.69363% of column missing
# NEW_RATIO_PREV_HOUR_APPR_PROCESS_START_MIN missing value counts: 238683, 0.66999% of column missing
# NEW_RATIO_PREV_HOUR_APPR_PROCESS_START_MAX missing value counts: 238682, 0.66998% of column missing
# NEW_RATIO_PREV_HOUR_APPR_PROCESS_START_MEAN missing value counts: 238682, 0.66998% of column missing
# NEW_RATIO_PREV_RATE_DOWN_PAYMENT_MIN missing value counts: 329592, 0.92517% of column missing
# NEW_RATIO_PREV_RATE_DOWN_PAYMENT_MAX missing value counts: 313295, 0.87942% of column missing
# NEW_RATIO_PREV_RATE_DOWN_PAYMENT_MEAN missing value counts: 313295, 0.87942% of column missing
# NEW_RATIO_PREV_DAYS_DECISION_MIN missing value counts: 238682, 0.66998% of column missing
# NEW_RATIO_PREV_DAYS_DECISION_MAX missing value counts: 238682, 0.66998% of column missing
# NEW_RATIO_PREV_DAYS_DECISION_MEAN missing value counts: 238682, 0.66998% of column missing
# NEW_RATIO_PREV_CNT_PAYMENT_MEAN missing value counts: 248930, 0.69875% of column missing
# NEW_RATIO_PREV_CNT_PAYMENT_SUM missing value counts: 238877, 0.67053% of column missing

# %%
# how many total missing values do we have?
total_cells = np.product(df.shape)

print('Total number of missing values in df: {:.0f}%'.format((total_missing/total_cells) * 100))
# Out:
# Total number of missing values in df: 27%

# %%
np.shape(df)
# Out:
# (356251, 666)
